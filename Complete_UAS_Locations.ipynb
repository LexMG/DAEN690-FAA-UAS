# %% [markdown]
# ## Import Statements and Read in Files

# %%
# Import Statements
import pandas as pd
import numpy as np

import geopy
from geopy.distance import geodesic

# %% [markdown]
# #### Import Dataset with UAS Locations in Standard Format that reference an AIRPORT (WITH bearing information)
#
# 2,812 total records

# %%
std_uas_airports = pd.read_csv('C:/Users/grace/OneDrive/Desktop/GMU/DAEN690/uas_latlong_standard_2812.csv')

# %%
std_uas_airports
# Out:
#       index                                            REMARKS  \
# 0         0  Aircraft observed alarge orange UAS with flash...
# 1         1  Aircraft observed a UAS while at 5,000 feet 11...
# 2         2  Aircraft observed a UAS while at 5,000 feet 11...
# 3         3  Aircraft observed a multi-colored UAS off the ...
# 4         4  Aircraft observed a triangular shaped, grey an...
# ...     ...                                                ...
# 2807   2813  Aircraft reported a medium sized quad-copter U...
# 2808   2814  Aircraft reported a quad-copter UAS at 12 O'cl...
# 2809   2815  Aircraft reported a UAS 3 NM N of MMU while E ...
# 2810   2816  Aircraft reported a UAS sensor hit while N bou...
# 2811   2817  Aircraft reported an unidentified aerial pheno...
#
#                    UAS_LOC IDENT  Distance Bearing  Distance_Kilometers  \
# 0      ['3 NM NNW of CLE']   CLE       3.0     NNW                5.556
# ...

# %% [markdown]
# #### Import Dataset with UAS Locations in Standard Format that reference a NAVAID (WITH bearing information)
#
# 177 total records

# %%
std_uas_airports = pd.read_csv('C:/Users/grace/OneDrive/Desktop/GMU/DAEN690/uas_latlong_standard_navaid_177.csv')

# %%
std_uas_airports
# Out:
#      index                                            REMARKS  \
# 0        0  Aircraft observed a UAS while NE bound at 3,00...
# 1        1  Aircraft observed a red UAS off the right wing...
# 2        2  Aircraft observed a UAS 8 NM N of SBJ VOR. No ...
# 3        3  Aircraft observed a gold colored UAS off the r...
# 4        4  Aircraft observed a black and red UAS heading ...
# ..     ...                                                ...
# 172    174  Aircraft reported a red UAS from theright side...
# 173    175  Aircraft reported a small blue UAS, pass appro...
# 174    176  Aircraft reported a UAS at co-altitude of 9,00...
# 175    177  Aircraft reported a NMAC with a silver UAS whi...
# 176    178  From MOR: Aircraft reported a NMAC with a flat...
#
#                   UAS_LOC IDENT  Distance Bearing  Distance_Kilometers  \
# 0     ['10 NM NE of COL']   COL      10.0      NE               18.520
# 1      ['1 NM NE of CRI']   CRI       1.0      NE                1.852
# ...
