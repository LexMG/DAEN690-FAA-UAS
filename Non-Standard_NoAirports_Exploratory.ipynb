# %% [markdown]
# ## Import needed libraries

# %%
import pandas as pd
import numpy as np

import geopy
from geopy.distance import geodesic

# %% [markdown]
# ## Read in the Non-Standard UAS locations csv file

# %%
non_std = pd.read_csv('C:/Users/Olga/Desktop/GMU/DAEN690/LEGO/non-std_format_uas_loc.csv')
non_std
# Out:
#                                                REMARKS              UAS_LOC  \
# 0    Aircraft reported UAS activity while entering ...     ['3NM SW ofIWA']
# 1    Reported a UAS off the left side at 500 feet w...    ['5 NM W of OPF']
# 2    Reported a black UAS off the left side of the ...    ['5 NM E of SAN']
# 3    Aircraft reported UAS pass below aircraft whil...  ['8 NM ESE of OAK']
# 4    Aircraft reported 3 large UAS at 3,000 feet 3....   ['5 NM SW of HND']
# ..                                                 ...                  ...
# 797  Facility manager observed a UAS from the groun...    ['3 NM N of EVV']
# 798  NWS Seal Beach Base personnel observed a UAS o...  ['72 NM SW of SLI']
# 799  PIC reports aircraft struck a multi-colored, 2...    ['1 NM E of ORD']
# 800  2120 EDT / 0120 UTC 08/23/2021\r\nENY3961 advi...    ['1 NM E of ORD']
# 801  Aircraft observed two UAS off the left side wh...    ['1 NM N of TPA']
#
#     IDENT                  NAME   LATITUDE   LONGITUDE ICAO_ID   dateonly  \
# 0     IWA  Phoenix-Mesa Gateway  33.307824 -111.655459    KIWA   1/6/2018
# 1     OPF  Miami-Opa Locka Exec  25.907417  -80.278222    KOPF  1/12/2018
# 2     SAN        San Diego Intl  32.733556 -117.189667    KSAN  1/12/2018
# 3     OAK    Metro Oakland Intl  37.721250 -122.221139    KOAK  1/15/2018
# 4     HND        Henderson Exec  35.972861 -115.134444    KHND  1/21/2018
# ..    ...                   ...        ...         ...     ...        ...
# 797   EVV       Evansville Rgnl  38.040806  -87.528500    KEVV  8/16/2021
# 798   SLI      Los Alamitos AAF  33.790030 -118.051420    KSLI  8/17/2021
# 799   ORD   Chicago O'hare Intl  41.976629  -87.907253    KORD  8/22/2021
# 800   ORD   Chicago O'hare Intl  41.976629  -87.907253    KORD  8/23/2021
# 801   TPA            Tampa Intl  27.975472  -82.533250    KTPA  8/25/2021
#
#     timeonly               DATE  ... IFRIVR.CEDAR AIRSPACECLASS.CEDAR  \
# 0       1:56  2018-01-06T01:56Z  ...          NaN                 NaN
# 1       3:54  2018-01-12T03:54Z  ...          NaN                 NaN
# 2       5:58  2018-01-12T05:58Z  ...          NaN                 NaN
# 3       5:30  2018-01-15T05:30Z  ...          NaN                 NaN
# 4       8:01  2018-01-21T08:01Z  ...          NaN                 NaN
# ..       ...                ...  ...          ...                 ...
# 797    22:02  2021-08-16T22:02Z  ...          NaN                 NaN
# 798    21:14  2021-08-17T21:14Z  ...          NaN                 NaN
# 799    23:39  2021-08-22T23:39Z  ...          IFR                   B
# 800     0:25  2021-08-23T00:25Z  ...          IFR                   B
# 801    15:35  2021-08-25T15:35Z  ...          NaN                 NaN
#
#      ACLOCATION.CEDAR ACALTITUDE.CEDAR ACHEADING.CEDAR  \
# 0                 NaN              NaN             NaN
# 1                 NaN              NaN             NaN
# 2                 NaN              NaN             NaN
# 3                 NaN              NaN             NaN
# 4                 NaN              NaN             NaN
# ..                ...              ...             ...
# 797               NaN              NaN             NaN
# 798               NaN              NaN             NaN
# 799    ORD R090 @1DME            250.0            90.0
# 800  1NM ENE ORD RY9C             20.0           360.0
# 801               NaN              NaN             NaN
#
#      RELATIVECLOCKPOSITION.CEDAR UASLONG.CEDAR UASLAT.CEDAR  \
# 0                            NaN           NaN          NaN
# 1                            NaN           NaN          NaN
# 2                            NaN           NaN          NaN
# 3                            NaN           NaN          NaN
# 4                            NaN           NaN          NaN
# ..                           ...           ...          ...
# 797                          NaN           NaN          NaN
# 798                          NaN           NaN          NaN
# 799                         12.0           NaN          NaN
# 800                          NaN           NaN          NaN
# 801                          NaN           NaN          NaN
#
#                                          SUMMARY.CEDAR  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 797                                                NaN
# 798                                                NaN
# 799  ENY3961 DEPARTED RWY09C FOR DTW. ONE MILE OFF ...
# 800  ENY3961 ADVISED C90 SHORTLY AFTER DEPARTING OR...
# 801                                                NaN
#
#                                       QAFINDINGS.CEDAR
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 797                                                NaN
# 798                                                NaN
# 799  QA reviewed. ENY3961 departed the ORD Airport ...
# 800              QA reviewed. All data in linked MOR.
# 801                                                NaN
#
# [802 rows x 31 columns]

# %% [markdown]
# ## Find all the null values and put them in new dataframe

# %%
non_std1 = non_std[non_std['NAME'].isnull()]
non_std1 = non_std1.drop(['NAME', 'LATITUDE', 'LONGITUDE', 'ICAO_ID'], axis=1)

non_std1 # There are 37 records with no airports
# Out:
#                                                REMARKS               UAS_LOC  \
# 73   FACSFAC VACAPES reports PIC reported a silver ...      ['6NM E of RBX']
# 95   Reported a UAS 500 feet below aircraft while 3...     ['3 NM E of OSI']
# 97   Reported a silver and white fixed wing UAS off...   ['11 NM SW of OSI']
# 137  PIC reported a black rotary UAS 50 feet below ...     ['2NM SW of PQF']
# 138  After departing RWY10 PIC reported a UAS below...    ['3NM NE of TIST']
# 159  PIC reported a black and brown UAS 1-meter in ...    ['10NM NW of CMK']
# 174  Forest Service Firehelicopter reported UASflew...   ['7 NM NNE of DBL']
# 206  LUKE AFB called and advised of a UAS sighting ...   ['20 NM SW of GBN']
# 223  Reported NMAC with a black with red UAS, 4 to ...   ['26 NM SE of JLI']
# 240  PIC reported a UASoff right side just below Ai...     ['6NM NE of COL']
# 242  PIC reported a dark colored UAS 1,000 feet abo...     ['10NM W of DPK']
# 299  Reported taking evasive action to avoid a UAS ...   ['16 NM SW of BQS']
# 412  Pilot reported a black UAS pass below while NW...    ['7NM ENE of OSI']
# 439  Pilot reported a white and orange UAS approxim...    ['1NM WSW of RWY']
# 440  While Aircraft was operating in the pattern at...      ['5NM N of RWY']
# 465  PIC reported UAS 300Ft below at 6000FT 7NM S o...      ['7NM S of ELB']
# 483  PIC reported a quad copter UAS pass 200 feetin...    ['10NM SE of FMG']
# 560  Reported a white quad copter at 1,000 FT 4 N o...       ['4 N of MUGU']
# 580  PIC reported a black phantom DJI quad copter U...   ['11NM ESE of BAE']
# 585  Reported observing a black, Phantom style Quad...   ['15NM WNW of OVR']
# 612  PIC reported a white UAS pass 500 feet belowwh...     ['9NM E of ETXV']
# 628  Reports a UAS 100 feet above the aircraft at 1...    ['10 NM W of SIE']
# 667  Aircraft was possibly struck by a UAS while de...    ['2 NM SE of OCN']
# 670  VFR aircraft observed a grey UAS off the 12 o'...     ['3NM NE of HAR']
# 686  PIC observed a black UAS with purple lights, 5...     ['8NM NE of CME']
# 697  FASFAC/VACAPES reported an aircraft observed a...   ['29 NM NE of CCV']
# 722  VFR aircraft observed a UAS off the left side ...      ['7NM N of FFU']
# 724  Aircraft (AIRTAC9) observed a UAS operating in...   ['12 NM NW of UTI']
# 732  San Diego PD observed a UAS 1.5NM S of RWY 27 ...      ['5NM S of RWY']
# 734  Security Guard observed a UAS pass overhead at...     ['4 NM E of RWY']
# 738  LUF airspace manager reported to ZAB aircraft ...  ['10 NM NW of TANK']
# 739  LUF airspace manager reported to ZAB aircraft ...  ['13 NM SE of BUGG']
# 744  Multiple aircraft observed multiple UAS off th...   ['24 NM SW of DIA']
# 749  MOR received at 16/0312. On 01/15/21 at 0117, ...   ['30 NM NW of MQO']
# 770  TJGI reports an aircraft observed a red quad-c...    ['3 NM W of TJIG']
# 777  Massachusetts State PD notified the Tower pers...   ['5 NM WSW of RWY']
# 778  Aircraft reported sensor hit at FL230 45 NM SE...   ['45 NM SE of GBN']
#
#     IDENT    dateonly timeonly               DATE   CALLSIGN  POD PRIMARYCODE  \
# 73    RBX    5/4/2018     0:06  2018-05-04T00:06Z    PARTY31  DEN         UAS
# 95    OSI   5/14/2018     5:46  2018-05-14T05:46Z     ASA330  DEN         UAS
# 97    OSI   5/14/2018     5:53  2018-05-14T05:53Z     N2809E  DEN         UAS
# 137   PQF   5/30/2018     0:31  2018-05-30T00:31Z      XAZTK  DEN         UAS
# 138  TIST   5/30/2018     5:00  2018-05-30T05:00Z     KAP249  DEN         UAS
# 159   CMK    6/4/2018     4:51  2018-06-04T04:51Z     DLH403  DEN         UAS
# 174   DBL   6/11/2018     5:53  2018-06-11T05:53Z        NaN  DEN         UAS
# 206   GBN   6/19/2018    22:24  2018-06-19T22:24Z        NaN  DEN         UAS
# 223   JLI   6/22/2018    23:22  2018-06-22T23:22Z    RANGR43  DEN         UAS
# 240   COL   6/30/2018     3:31  2018-06-30T03:31Z    RPA4415  DEN         UAS
# 242   DPK   6/30/2018     4:20  2018-06-30T04:20Z       FIN6  DEN         UAS
# 299   BQS    8/3/2018     3:13  2018-08-03T03:13Z     N955JL  DEN         UAS
# 412   OSI   11/9/2018     1:01  2018-11-09T01:01Z        UAL  DEN         UAS
# 439   RWY   12/8/2018    23:21  2018-12-08T23:21Z      N43RQ  DEN         UAS
# 440   RWY  12/13/2018     0:44  2018-12-13T00:44Z     N6969M  DEN         UAS
# 465   ELB   1/27/2019    23:10  2019-01-27T23:10Z      N21SH  DEN         UAS
# 483   FMG   2/11/2019     7:11  2019-02-11T07:11Z    SKW3574  DEN         UAS
# 560  MUGU    5/9/2019     5:25  2019-05-09T05:25Z     LIMO42  DEN         UAS
# 580   BAE   5/18/2019     6:28  2019-05-18T06:28Z     N923JK  DEN         UAS
# 585   OVR   5/23/2019     2:19  2019-05-23T02:19Z     N737NU  DEN         UAS
# 612  ETXV   6/10/2019     1:30  2019-06-10T01:30Z     N523GC  DEN         UAS
# 628   SIE   6/19/2019     1:23  2019-06-19T01:23Z    PDT4865  DEN         UAS
# 667   OCN   8/21/2019    20:00  2019-08-21T20:00Z      JUMP1  DEN         UAS
# 670   HAR    9/8/2019    21:30  2019-09-08T21:30Z     N35501  DEN         UAS
# 686   CME  11/12/2019    17:54  2019-11-12T17:54Z  CAREFLT23  DEN         UAS
# 697   CCV   2/10/2020    13:54  2020-02-10T13:54Z    RINGO02  DEN         UAS
# 722   FFU   6/27/2020     5:11  2020-06-27T05:11Z     N40670  DEN         UAS
# 724   UTI   7/15/2020     2:25  2020-07-15T02:25Z      N42FC  DEN         UAS
# 732   RWY  11/11/2020     3:01  2020-11-11T03:01Z        NaN  DEN         UAS
# 734   RWY  11/16/2020    16:57  2020-11-16T16:57Z        NaN  DEN         UAS
# 738  TANK  12/14/2020    23:04  2020-12-14T23:04Z      ROOK1  DEN         UAS
# 739  BUGG  12/14/2020    23:55  2020-12-14T23:55Z    DEADLY1  DEN         UAS
# 744   DIA  12/25/2020     3:20  2020-12-25T03:20Z    AIP1813  DEN         UAS
# 749   MQO   1/16/2021     3:12  2021-01-16T03:12Z     N888JV  DEN         UAS
# 770  TJIG    4/5/2021    18:51  2021-04-05T18:51Z     N4165U  DEN         UAS
# 777   RWY   4/28/2021    21:23  2021-04-28T21:23Z        NaN  DEN         UAS
# 778   GBN   4/30/2021    17:15  2021-04-30T17:15Z      PREY1  DEN         UAS
#
#              SECONDARYCODES  ... IFRIVR.CEDAR  AIRSPACECLASS.CEDAR  \
# 73                      NaN  ...          NaN                  NaN
# 95                      NaN  ...          NaN                  NaN
# 97                      NaN  ...          NaN                  NaN
# 137                     NaN  ...          NaN                  NaN
# 138                     NaN  ...          NaN                  NaN
# 159                     NaN  ...          NaN                  NaN
# 174                     NaN  ...          NaN                  NaN
# 206                     NaN  ...          NaN                  NaN
# 223                     NaN  ...          NaN                  NaN
# 240                     NaN  ...          NaN                  NaN
# 242                     NaN  ...          NaN                  NaN
# 299                   PAGED  ...          NaN                  NaN
# 412                     NaN  ...          NaN                  NaN
# 439                     NaN  ...          NaN                  NaN
# 440                     NaN  ...          NaN                  NaN
# 465                     NaN  ...          NaN                  NaN
# 483                     NaN  ...          NaN                  NaN
# 560                     NaN  ...          NaN                  NaN
# 580                     NaN  ...          NaN                  NaN
# 585                     NaN  ...          NaN                  NaN
# 612                     NaN  ...          NaN                  NaN
# 628                     NaN  ...          NaN                  NaN
# 667                     NaN  ...          NaN                  NaN
# 670                     NaN  ...          NaN                  NaN
# 686                     NaN  ...          NaN                  NaN
# 697                     NaN  ...          NaN                  NaN
# 722                     NaN  ...          NaN                  NaN
# 724                     NaN  ...          NaN                  NaN
# 732                     NaN  ...          NaN                  NaN
# 734                   OTHER  ...          NaN                  NaN
# 738       NOTIFICATION-NONE  ...          NaN                  NaN
# 739       NOTIFICATION-NONE  ...          NaN                  NaN
# 744                     NaN  ...          NaN                  NaN
# 749  MOR, NOTIFICATION-LATE  ...          NaN                  NaN
# 770                     NaN  ...          NaN                  NaN
# 777                     NaN  ...          NaN                  NaN
# 778                     NaN  ...          NaN                  NaN
#
#     ACLOCATION.CEDAR ACALTITUDE.CEDAR ACHEADING.CEDAR  \
# 73               NaN              NaN             NaN
# 95               NaN              NaN             NaN
# 97               NaN              NaN             NaN
# 137              NaN              NaN             NaN
# 138              NaN              NaN             NaN
# 159              NaN              NaN             NaN
# 174              NaN              NaN             NaN
# 206              NaN              NaN             NaN
# 223              NaN              NaN             NaN
# 240              NaN              NaN             NaN
# 242              NaN              NaN             NaN
# 299              NaN              NaN             NaN
# 412              NaN              NaN             NaN
# 439              NaN              NaN             NaN
# 440              NaN              NaN             NaN
# 465              NaN              NaN             NaN
# 483              NaN              NaN             NaN
# 560              NaN              NaN             NaN
# 580              NaN              NaN             NaN
# 585              NaN              NaN             NaN
# 612              NaN              NaN             NaN
# 628              NaN              NaN             NaN
# 667              NaN              NaN             NaN
# 670              NaN              NaN             NaN
# 686              NaN              NaN             NaN
# 697              NaN              NaN             NaN
# 722              NaN              NaN             NaN
# 724              NaN              NaN             NaN
# 732              NaN              NaN             NaN
# 734              NaN              NaN             NaN
# 738              NaN              NaN             NaN
# 739              NaN              NaN             NaN
# 744              NaN              NaN             NaN
# 749              NaN              NaN             NaN
# 770              NaN              NaN             NaN
# 777              NaN              NaN             NaN
# 778              NaN              NaN             NaN
#
#     RELATIVECLOCKPOSITION.CEDAR UASLONG.CEDAR UASLAT.CEDAR SUMMARY.CEDAR  \
# 73                          NaN           NaN          NaN           NaN
# 95                          NaN           NaN          NaN           NaN
# 97                          NaN           NaN          NaN           NaN
# 137                         NaN           NaN          NaN           NaN
# 138                         NaN           NaN          NaN           NaN
# 159                         NaN           NaN          NaN           NaN
# 174                         NaN           NaN          NaN           NaN
# 206                         NaN           NaN          NaN           NaN
# 223                         NaN           NaN          NaN           NaN
# 240                         NaN           NaN          NaN           NaN
# 242                         NaN           NaN          NaN           NaN
# 299                         NaN           NaN          NaN           NaN
# 412                         NaN           NaN          NaN           NaN
# 439                         NaN           NaN          NaN           NaN
# 440                         NaN           NaN          NaN           NaN
# 465                         NaN           NaN          NaN           NaN
# 483                         NaN           NaN          NaN           NaN
# 560                         NaN           NaN          NaN           NaN
# 580                         NaN           NaN          NaN           NaN
# 585                         NaN           NaN          NaN           NaN
# 612                         NaN           NaN          NaN           NaN
# 628                         NaN           NaN          NaN           NaN
# 667                         NaN           NaN          NaN           NaN
# 670                         NaN           NaN          NaN           NaN
# 686                         NaN           NaN          NaN           NaN
# 697                         NaN           NaN          NaN           NaN
# 722                         NaN           NaN          NaN           NaN
# 724                         NaN           NaN          NaN           NaN
# 732                         NaN           NaN          NaN           NaN
# 734                         NaN           NaN          NaN           NaN
# 738                         NaN           NaN          NaN           NaN
# 739                         NaN           NaN          NaN           NaN
# 744                         NaN           NaN          NaN           NaN
# 749                         NaN           NaN          NaN           NaN
# 770                         NaN           NaN          NaN           NaN
# 777                         NaN           NaN          NaN           NaN
# 778                         NaN           NaN          NaN           NaN
#
#     QAFINDINGS.CEDAR
# 73               NaN
# 95               NaN
# 97               NaN
# 137              NaN
# 138              NaN
# 159              NaN
# 174              NaN
# 206              NaN
# 223              NaN
# 240              NaN
# 242              NaN
# 299              NaN
# 412              NaN
# 439              NaN
# 440              NaN
# 465              NaN
# 483              NaN
# 560              NaN
# 580              NaN
# 585              NaN
# 612              NaN
# 628              NaN
# 667              NaN
# 670              NaN
# 686              NaN
# 697              NaN
# 722              NaN
# 724              NaN
# 732              NaN
# 734              NaN
# 738              NaN
# 739              NaN
# 744              NaN
# 749              NaN
# 770              NaN
# 777              NaN
# 778              NaN
#
# [37 rows x 27 columns]

# %% [markdown]
# ## Read in the NAVAID dataset

# %%
navaid = pd.read_csv('C:/Users/Olga/Desktop/GMU/DAEN690/LEGO/NAVAID_Cleaned.csv')
navaid
# Out:
#        LONGITUDE   LATITUDE IDENT        NAME_TXT
# 0    -176.676024  51.871896   ADK   MOUNT MOFFETT
# 1    -151.744257  68.136626   AKP  ANAKTUVUK PASS
# 2    -149.960164  61.167868   TED       ANCHORAGE
# 3    -149.769204  61.255004   EDF       ELMENDORF
# 4    -159.597931  61.590169   ANI           ANIAK
# ...          ...        ...   ...             ...
# 1669 -156.788152  71.273426   BRW          BARROW
# 1670 -156.781302  71.282300   VIR     BROWERVILLE
# 1671  -75.164524  43.026523   UCA           UTICA
# 1672  -90.434470  40.937351   GBG       GALESBURG
# 1673 -104.804750  47.133380   GDV        GLENDIVE
#
# [1674 rows x 4 columns]

# %% [markdown]
# ## Join the NAVAID dataset with the remaining 37 records

# %%
join_uas_nav = pd.merge(non_std1, navaid, on='IDENT', how='left')
join_uas_nav # 25 records were successfully joined using the navaid dataset
# Out:
#                                               REMARKS               UAS_LOC  \
# 0   FACSFAC VACAPES reports PIC reported a silver ...      ['6NM E of RBX']
# 1   Reported a UAS 500 feet below aircraft while 3...     ['3 NM E of OSI']
# 2   Reported a silver and white fixed wing UAS off...   ['11 NM SW of OSI']
# 3   PIC reported a black rotary UAS 50 feet below ...     ['2NM SW of PQF']
# 4   After departing RWY10 PIC reported a UAS below...    ['3NM NE of TIST']
# 5   PIC reported a black and brown UAS 1-meter in ...    ['10NM NW of CMK']
# 6   Forest Service Firehelicopter reported UASflew...   ['7 NM NNE of DBL']
# 7   LUKE AFB called and advised of a UAS sighting ...   ['20 NM SW of GBN']
# 8   Reported NMAC with a black with red UAS, 4 to ...   ['26 NM SE of JLI']
# 9   PIC reported a UASoff right side just below Ai...     ['6NM NE of COL']
# 10  PIC reported a dark colored UAS 1,000 feet abo...     ['10NM W of DPK']
# 11  Reported taking evasive action to avoid a UAS ...   ['16 NM SW of BQS']
# 12  Pilot reported a black UAS pass below while NW...    ['7NM ENE of OSI']
# 13  Pilot reported a white and orange UAS approxim...    ['1NM WSW of RWY']
# 14  While Aircraft was operating in the pattern at...      ['5NM N of RWY']
# 15  PIC reported UAS 300Ft below at 6000FT 7NM S o...      ['7NM S of ELB']
# 16  PIC reported a quad copter UAS pass 200 feetin...    ['10NM SE of FMG']
# 17  Reported a white quad copter at 1,000 FT 4 N o...       ['4 N of MUGU']
# 18  PIC reported a black phantom DJI quad copter U...   ['11NM ESE of BAE']
# 19  Reported observing a black, Phantom style Quad...   ['15NM WNW of OVR']
# 20  PIC reported a white UAS pass 500 feet belowwh...     ['9NM E of ETXV']
# 21  Reports a UAS 100 feet above the aircraft at 1...    ['10 NM W of SIE']
# 22  Aircraft was possibly struck by a UAS while de...    ['2 NM SE of OCN']
# 23  VFR aircraft observed a grey UAS off the 12 o'...     ['3NM NE of HAR']
# 24  PIC observed a black UAS with purple lights, 5...     ['8NM NE of CME']
# 25  FASFAC/VACAPES reported an aircraft observed a...   ['29 NM NE of CCV']
# 26  VFR aircraft observed a UAS off the left side ...      ['7NM N of FFU']
# 27  Aircraft (AIRTAC9) observed a UAS operating in...   ['12 NM NW of UTI']
# 28  San Diego PD observed a UAS 1.5NM S of RWY 27 ...      ['5NM S of RWY']
# 29  Security Guard observed a UAS pass overhead at...     ['4 NM E of RWY']
# 30  LUF airspace manager reported to ZAB aircraft ...  ['10 NM NW of TANK']
# 31  LUF airspace manager reported to ZAB aircraft ...  ['13 NM SE of BUGG']
# 32  Multiple aircraft observed multiple UAS off th...   ['24 NM SW of DIA']
# 33  MOR received at 16/0312. On 01/15/21 at 0117, ...   ['30 NM NW of MQO']
# 34  TJGI reports an aircraft observed a red quad-c...    ['3 NM W of TJIG']
# 35  Massachusetts State PD notified the Tower pers...   ['5 NM WSW of RWY']
# 36  Aircraft reported sensor hit at FL230 45 NM SE...   ['45 NM SE of GBN']
#
#    IDENT    dateonly timeonly               DATE   CALLSIGN  POD PRIMARYCODE  \
# 0    RBX    5/4/2018     0:06  2018-05-04T00:06Z    PARTY31  DEN         UAS
# 1    OSI   5/14/2018     5:46  2018-05-14T05:46Z     ASA330  DEN         UAS
# 2    OSI   5/14/2018     5:53  2018-05-14T05:53Z     N2809E  DEN         UAS
# 3    PQF   5/30/2018     0:31  2018-05-30T00:31Z      XAZTK  DEN         UAS
# 4   TIST   5/30/2018     5:00  2018-05-30T05:00Z     KAP249  DEN         UAS
# 5    CMK    6/4/2018     4:51  2018-06-04T04:51Z     DLH403  DEN         UAS
# 6    DBL   6/11/2018     5:53  2018-06-11T05:53Z        NaN  DEN         UAS
# 7    GBN   6/19/2018    22:24  2018-06-19T22:24Z        NaN  DEN         UAS
# 8    JLI   6/22/2018    23:22  2018-06-22T23:22Z    RANGR43  DEN         UAS
# 9    COL   6/30/2018     3:31  2018-06-30T03:31Z    RPA4415  DEN         UAS
# 10   DPK   6/30/2018     4:20  2018-06-30T04:20Z       FIN6  DEN         UAS
# 11   BQS    8/3/2018     3:13  2018-08-03T03:13Z     N955JL  DEN         UAS
# 12   OSI   11/9/2018     1:01  2018-11-09T01:01Z        UAL  DEN         UAS
# 13   RWY   12/8/2018    23:21  2018-12-08T23:21Z      N43RQ  DEN         UAS
# 14   RWY  12/13/2018     0:44  2018-12-13T00:44Z     N6969M  DEN         UAS
# 15   ELB   1/27/2019    23:10  2019-01-27T23:10Z      N21SH  DEN         UAS
# 16   FMG   2/11/2019     7:11  2019-02-11T07:11Z    SKW3574  DEN         UAS
# 17  MUGU    5/9/2019     5:25  2019-05-09T05:25Z     LIMO42  DEN         UAS
# 18   BAE   5/18/2019     6:28  2019-05-18T06:28Z     N923JK  DEN         UAS
# 19   OVR   5/23/2019     2:19  2019-05-23T02:19Z     N737NU  DEN         UAS
# 20  ETXV   6/10/2019     1:30  2019-06-10T01:30Z     N523GC  DEN         UAS
# 21   SIE   6/19/2019     1:23  2019-06-19T01:23Z    PDT4865  DEN         UAS
# 22   OCN   8/21/2019    20:00  2019-08-21T20:00Z      JUMP1  DEN         UAS
# 23   HAR    9/8/2019    21:30  2019-09-08T21:30Z     N35501  DEN         UAS
# 24   CME  11/12/2019    17:54  2019-11-12T17:54Z  CAREFLT23  DEN         UAS
# 25   CCV   2/10/2020    13:54  2020-02-10T13:54Z    RINGO02  DEN         UAS
# 26   FFU   6/27/2020     5:11  2020-06-27T05:11Z     N40670  DEN         UAS
# 27   UTI   7/15/2020     2:25  2020-07-15T02:25Z      N42FC  DEN         UAS
# 28   RWY  11/11/2020     3:01  2020-11-11T03:01Z        NaN  DEN         UAS
# 29   RWY  11/16/2020    16:57  2020-11-16T16:57Z        NaN  DEN         UAS
# 30  TANK  12/14/2020    23:04  2020-12-14T23:04Z      ROOK1  DEN         UAS
# 31  BUGG  12/14/2020    23:55  2020-12-14T23:55Z    DEADLY1  DEN         UAS
# 32   DIA  12/25/2020     3:20  2020-12-25T03:20Z    AIP1813  DEN         UAS
# 33   MQO   1/16/2021     3:12  2021-01-16T03:12Z     N888JV  DEN         UAS
# 34  TJIG    4/5/2021    18:51  2021-04-05T18:51Z     N4165U  DEN         UAS
# 35   RWY   4/28/2021    21:23  2021-04-28T21:23Z        NaN  DEN         UAS
# 36   GBN   4/30/2021    17:15  2021-04-30T17:15Z      PREY1  DEN         UAS
#
#             SECONDARYCODES  ... ACALTITUDE.CEDAR  ACHEADING.CEDAR  \
# 0                      NaN  ...              NaN              NaN
# 1                      NaN  ...              NaN              NaN
# 2                      NaN  ...              NaN              NaN
# 3                      NaN  ...              NaN              NaN
# 4                      NaN  ...              NaN              NaN
# 5                      NaN  ...              NaN              NaN
# 6                      NaN  ...              NaN              NaN
# 7                      NaN  ...              NaN              NaN
# 8                      NaN  ...              NaN              NaN
# 9                      NaN  ...              NaN              NaN
# 10                     NaN  ...              NaN              NaN
# 11                   PAGED  ...              NaN              NaN
# 12                     NaN  ...              NaN              NaN
# 13                     NaN  ...              NaN              NaN
# 14                     NaN  ...              NaN              NaN
# 15                     NaN  ...              NaN              NaN
# 16                     NaN  ...              NaN              NaN
# 17                     NaN  ...              NaN              NaN
# 18                     NaN  ...              NaN              NaN
# 19                     NaN  ...              NaN              NaN
# 20                     NaN  ...              NaN              NaN
# 21                     NaN  ...              NaN              NaN
# 22                     NaN  ...              NaN              NaN
# 23                     NaN  ...              NaN              NaN
# 24                     NaN  ...              NaN              NaN
# 25                     NaN  ...              NaN              NaN
# 26                     NaN  ...              NaN              NaN
# 27                     NaN  ...              NaN              NaN
# 28                     NaN  ...              NaN              NaN
# 29                   OTHER  ...              NaN              NaN
# 30       NOTIFICATION-NONE  ...              NaN              NaN
# 31       NOTIFICATION-NONE  ...              NaN              NaN
# 32                     NaN  ...              NaN              NaN
# 33  MOR, NOTIFICATION-LATE  ...              NaN              NaN
# 34                     NaN  ...              NaN              NaN
# 35                     NaN  ...              NaN              NaN
# 36                     NaN  ...              NaN              NaN
#
#    RELATIVECLOCKPOSITION.CEDAR UASLONG.CEDAR UASLAT.CEDAR SUMMARY.CEDAR  \
# 0                          NaN           NaN          NaN           NaN
# 1                          NaN           NaN          NaN           NaN
# 2                          NaN           NaN          NaN           NaN
# 3                          NaN           NaN          NaN           NaN
# 4                          NaN           NaN          NaN           NaN
# 5                          NaN           NaN          NaN           NaN
# 6                          NaN           NaN          NaN           NaN
# 7                          NaN           NaN          NaN           NaN
# 8                          NaN           NaN          NaN           NaN
# 9                          NaN           NaN          NaN           NaN
# 10                         NaN           NaN          NaN           NaN
# 11                         NaN           NaN          NaN           NaN
# 12                         NaN           NaN          NaN           NaN
# 13                         NaN           NaN          NaN           NaN
# 14                         NaN           NaN          NaN           NaN
# 15                         NaN           NaN          NaN           NaN
# 16                         NaN           NaN          NaN           NaN
# 17                         NaN           NaN          NaN           NaN
# 18                         NaN           NaN          NaN           NaN
# 19                         NaN           NaN          NaN           NaN
# 20                         NaN           NaN          NaN           NaN
# 21                         NaN           NaN          NaN           NaN
# 22                         NaN           NaN          NaN           NaN
# 23                         NaN           NaN          NaN           NaN
# 24                         NaN           NaN          NaN           NaN
# 25                         NaN           NaN          NaN           NaN
# 26                         NaN           NaN          NaN           NaN
# 27                         NaN           NaN          NaN           NaN
# 28                         NaN           NaN          NaN           NaN
# 29                         NaN           NaN          NaN           NaN
# 30                         NaN           NaN          NaN           NaN
# 31                         NaN           NaN          NaN           NaN
# 32                         NaN           NaN          NaN           NaN
# 33                         NaN           NaN          NaN           NaN
# 34                         NaN           NaN          NaN           NaN
# 35                         NaN           NaN          NaN           NaN
# 36                         NaN           NaN          NaN           NaN
#
#    QAFINDINGS.CEDAR   LONGITUDE   LATITUDE         NAME_TXT
# 0               NaN  -75.696939  35.920508  WRIGHT BROTHERS
# 1               NaN -122.281316  37.392505         WOODSIDE
# 2               NaN -122.281316  37.392505         WOODSIDE
# 3               NaN  -96.529127  32.809373         MESQUITE
# 4               NaN         NaN        NaN              NaN
# 5               NaN  -73.581330  41.280102           CARMEL
# 6               NaN -106.894691  39.439352        RED TABLE
# 7               NaN -112.674283  32.956263        GILA BEND
# 8               NaN -116.585947  33.140463           JULIAN
# 9               NaN  -74.159729  40.311641       COLTS NECK
# 10              NaN  -73.303659  40.791758        DEER PARK
# 11              NaN  -93.875285  39.630563          BRAYMER
# 12              NaN -122.281316  37.392505         WOODSIDE
# 13              NaN         NaN        NaN              NaN
# 14              NaN         NaN        NaN              NaN
# 15              NaN -117.731096  33.676035          EL TORO
# 16              NaN -119.656084  39.531270          MUSTANG
# 17              NaN         NaN        NaN              NaN
# 18              NaN  -88.284351  43.116861           BADGER
# 19              NaN  -95.736861  41.167174            OMAHA
# 20              NaN         NaN        NaN              NaN
# 21              NaN  -74.800345  39.095517         SEA ISLE
# 22              NaN -117.417733  33.240639        OCEANSIDE
# 23              NaN  -77.069561  40.302248       HARRISBURG
# 24              NaN -104.621255  33.337484           CHISUM
# 25              NaN  -75.997655  37.347546     CAPE CHARLES
# 26              NaN -111.940543  40.274901        FAIRFIELD
# 27              NaN -113.517912  37.017625        ST GEORGE
# 28              NaN         NaN        NaN              NaN
# 29              NaN         NaN        NaN              NaN
# 30              NaN         NaN        NaN              NaN
# 31              NaN         NaN        NaN              NaN
# 32              NaN         NaN        NaN              NaN
# 33              NaN -120.759579  35.252260        MORRO BAY
# 34              NaN         NaN        NaN              NaN
# 35              NaN         NaN        NaN              NaN
# 36              NaN -112.674283  32.956263        GILA BEND
#
# [37 rows x 30 columns]

# %%
nav_loc = join_uas_nav[join_uas_nav['NAME_TXT'].notnull()]
nav_loc
# Out:
#                                               REMARKS              UAS_LOC  \
# 0   FACSFAC VACAPES reports PIC reported a silver ...     ['6NM E of RBX']
# 1   Reported a UAS 500 feet below aircraft while 3...    ['3 NM E of OSI']
# 2   Reported a silver and white fixed wing UAS off...  ['11 NM SW of OSI']
# 3   PIC reported a black rotary UAS 50 feet below ...    ['2NM SW of PQF']
# 5   PIC reported a black and brown UAS 1-meter in ...   ['10NM NW of CMK']
# 6   Forest Service Firehelicopter reported UASflew...  ['7 NM NNE of DBL']
# 7   LUKE AFB called and advised of a UAS sighting ...  ['20 NM SW of GBN']
# 8   Reported NMAC with a black with red UAS, 4 to ...  ['26 NM SE of JLI']
# 9   PIC reported a UASoff right side just below Ai...    ['6NM NE of COL']
# 10  PIC reported a dark colored UAS 1,000 feet abo...    ['10NM W of DPK']
# 11  Reported taking evasive action to avoid a UAS ...  ['16 NM SW of BQS']
# 12  Pilot reported a black UAS pass below while NW...   ['7NM ENE of OSI']
# 15  PIC reported UAS 300Ft below at 6000FT 7NM S o...     ['7NM S of ELB']
# 16  PIC reported a quad copter UAS pass 200 feetin...   ['10NM SE of FMG']
# 18  PIC reported a black phantom DJI quad copter U...  ['11NM ESE of BAE']
# 19  Reported observing a black, Phantom style Quad...  ['15NM WNW of OVR']
# 21  Reports a UAS 100 feet above the aircraft at 1...   ['10 NM W of SIE']
# 22  Aircraft was possibly struck by a UAS while de...   ['2 NM SE of OCN']
# 23  VFR aircraft observed a grey UAS off the 12 o'...    ['3NM NE of HAR']
# 24  PIC observed a black UAS with purple lights, 5...    ['8NM NE of CME']
# 25  FASFAC/VACAPES reported an aircraft observed a...  ['29 NM NE of CCV']
# 26  VFR aircraft observed a UAS off the left side ...     ['7NM N of FFU']
# 27  Aircraft (AIRTAC9) observed a UAS operating in...  ['12 NM NW of UTI']
# 33  MOR received at 16/0312. On 01/15/21 at 0117, ...  ['30 NM NW of MQO']
# 36  Aircraft reported sensor hit at FL230 45 NM SE...  ['45 NM SE of GBN']
#
#    IDENT    dateonly timeonly               DATE   CALLSIGN  POD PRIMARYCODE  \
# 0    RBX    5/4/2018     0:06  2018-05-04T00:06Z    PARTY31  DEN         UAS
# 1    OSI   5/14/2018     5:46  2018-05-14T05:46Z     ASA330  DEN         UAS
# 2    OSI   5/14/2018     5:53  2018-05-14T05:53Z     N2809E  DEN         UAS
# 3    PQF   5/30/2018     0:31  2018-05-30T00:31Z      XAZTK  DEN         UAS
# 5    CMK    6/4/2018     4:51  2018-06-04T04:51Z     DLH403  DEN         UAS
# 6    DBL   6/11/2018     5:53  2018-06-11T05:53Z        NaN  DEN         UAS
# 7    GBN   6/19/2018    22:24  2018-06-19T22:24Z        NaN  DEN         UAS
# 8    JLI   6/22/2018    23:22  2018-06-22T23:22Z    RANGR43  DEN         UAS
# 9    COL   6/30/2018     3:31  2018-06-30T03:31Z    RPA4415  DEN         UAS
# 10   DPK   6/30/2018     4:20  2018-06-30T04:20Z       FIN6  DEN         UAS
# 11   BQS    8/3/2018     3:13  2018-08-03T03:13Z     N955JL  DEN         UAS
# 12   OSI   11/9/2018     1:01  2018-11-09T01:01Z        UAL  DEN         UAS
# 15   ELB   1/27/2019    23:10  2019-01-27T23:10Z      N21SH  DEN         UAS
# 16   FMG   2/11/2019     7:11  2019-02-11T07:11Z    SKW3574  DEN         UAS
# 18   BAE   5/18/2019     6:28  2019-05-18T06:28Z     N923JK  DEN         UAS
# 19   OVR   5/23/2019     2:19  2019-05-23T02:19Z     N737NU  DEN         UAS
# 21   SIE   6/19/2019     1:23  2019-06-19T01:23Z    PDT4865  DEN         UAS
# 22   OCN   8/21/2019    20:00  2019-08-21T20:00Z      JUMP1  DEN         UAS
# 23   HAR    9/8/2019    21:30  2019-09-08T21:30Z     N35501  DEN         UAS
# 24   CME  11/12/2019    17:54  2019-11-12T17:54Z  CAREFLT23  DEN         UAS
# 25   CCV   2/10/2020    13:54  2020-02-10T13:54Z    RINGO02  DEN         UAS
# 26   FFU   6/27/2020     5:11  2020-06-27T05:11Z     N40670  DEN         UAS
# 27   UTI   7/15/2020     2:25  2020-07-15T02:25Z      N42FC  DEN         UAS
# 33   MQO   1/16/2021     3:12  2021-01-16T03:12Z     N888JV  DEN         UAS
# 36   GBN   4/30/2021    17:15  2021-04-30T17:15Z      PREY1  DEN         UAS
#
#             SECONDARYCODES  ... ACALTITUDE.CEDAR  ACHEADING.CEDAR  \
# 0                      NaN  ...              NaN              NaN
# 1                      NaN  ...              NaN              NaN
# 2                      NaN  ...              NaN              NaN
# 3                      NaN  ...              NaN              NaN
# 5                      NaN  ...              NaN              NaN
# 6                      NaN  ...              NaN              NaN
# 7                      NaN  ...              NaN              NaN
# 8                      NaN  ...              NaN              NaN
# 9                      NaN  ...              NaN              NaN
# 10                     NaN  ...              NaN              NaN
# 11                   PAGED  ...              NaN              NaN
# 12                     NaN  ...              NaN              NaN
# 15                     NaN  ...              NaN              NaN
# 16                     NaN  ...              NaN              NaN
# 18                     NaN  ...              NaN              NaN
# 19                     NaN  ...              NaN              NaN
# 21                     NaN  ...              NaN              NaN
# 22                     NaN  ...              NaN              NaN
# 23                     NaN  ...              NaN              NaN
# 24                     NaN  ...              NaN              NaN
# 25                     NaN  ...              NaN              NaN
# 26                     NaN  ...              NaN              NaN
# 27                     NaN  ...              NaN              NaN
# 33  MOR, NOTIFICATION-LATE  ...              NaN              NaN
# 36                     NaN  ...              NaN              NaN
#
#    RELATIVECLOCKPOSITION.CEDAR UASLONG.CEDAR UASLAT.CEDAR SUMMARY.CEDAR  \
# 0                          NaN           NaN          NaN           NaN
# 1                          NaN           NaN          NaN           NaN
# 2                          NaN           NaN          NaN           NaN
# 3                          NaN           NaN          NaN           NaN
# 5                          NaN           NaN          NaN           NaN
# 6                          NaN           NaN          NaN           NaN
# 7                          NaN           NaN          NaN           NaN
# 8                          NaN           NaN          NaN           NaN
# 9                          NaN           NaN          NaN           NaN
# 10                         NaN           NaN          NaN           NaN
# 11                         NaN           NaN          NaN           NaN
# 12                         NaN           NaN          NaN           NaN
# 15                         NaN           NaN          NaN           NaN
# 16                         NaN           NaN          NaN           NaN
# 18                         NaN           NaN          NaN           NaN
# 19                         NaN           NaN          NaN           NaN
# 21                         NaN           NaN          NaN           NaN
# 22                         NaN           NaN          NaN           NaN
# 23                         NaN           NaN          NaN           NaN
# 24                         NaN           NaN          NaN           NaN
# 25                         NaN           NaN          NaN           NaN
# 26                         NaN           NaN          NaN           NaN
# 27                         NaN           NaN          NaN           NaN
# 33                         NaN           NaN          NaN           NaN
# 36                         NaN           NaN          NaN           NaN
#
#    QAFINDINGS.CEDAR   LONGITUDE   LATITUDE         NAME_TXT
# 0               NaN  -75.696939  35.920508  WRIGHT BROTHERS
# 1               NaN -122.281316  37.392505         WOODSIDE
# 2               NaN -122.281316  37.392505         WOODSIDE
# 3               NaN  -96.529127  32.809373         MESQUITE
# 5               NaN  -73.581330  41.280102           CARMEL
# 6               NaN -106.894691  39.439352        RED TABLE
# 7               NaN -112.674283  32.956263        GILA BEND
# 8               NaN -116.585947  33.140463           JULIAN
# 9               NaN  -74.159729  40.311641       COLTS NECK
# 10              NaN  -73.303659  40.791758        DEER PARK
# 11              NaN  -93.875285  39.630563          BRAYMER
# 12              NaN -122.281316  37.392505         WOODSIDE
# 15              NaN -117.731096  33.676035          EL TORO
# 16              NaN -119.656084  39.531270          MUSTANG
# 18              NaN  -88.284351  43.116861           BADGER
# 19              NaN  -95.736861  41.167174            OMAHA
# 21              NaN  -74.800345  39.095517         SEA ISLE
# 22              NaN -117.417733  33.240639        OCEANSIDE
# 23              NaN  -77.069561  40.302248       HARRISBURG
# 24              NaN -104.621255  33.337484           CHISUM
# 25              NaN  -75.997655  37.347546     CAPE CHARLES
# 26              NaN -111.940543  40.274901        FAIRFIELD
# 27              NaN -113.517912  37.017625        ST GEORGE
# 33              NaN -120.759579  35.252260        MORRO BAY
# 36              NaN -112.674283  32.956263        GILA BEND
#
# [25 rows x 30 columns]

# %%
# Export the 25 records to seperate csv file
nav_loc.to_csv('non-std_uasLoc_Nav.csv', index = False)

# %% [markdown]
# ##  Check the unmatched records

# %%
len(join_uas_nav[join_uas_nav['NAME_TXT'].isnull()])
# We have 12 remaining records
# Out:
# 12

# %% [markdown]
# ## Export the remaining 12 records to new dataframe

# %%
remaining = join_uas_nav[join_uas_nav['NAME_TXT'].isnull()]
remaining.to_csv('non-std_uasLoc_noAir_noNav.csv', index = False)

# %% [markdown]
# ## Check for runways in the remaining records

# %%
rwy = remaining[remaining["IDENT"] == 'RWY']
rwy # We have 5 records
# Out:
#                                               REMARKS              UAS_LOC  \
# 13  Pilot reported a white and orange UAS approxim...   ['1NM WSW of RWY']
# 14  While Aircraft was operating in the pattern at...     ['5NM N of RWY']
# 28  San Diego PD observed a UAS 1.5NM S of RWY 27 ...     ['5NM S of RWY']
# 29  Security Guard observed a UAS pass overhead at...    ['4 NM E of RWY']
# 35  Massachusetts State PD notified the Tower pers...  ['5 NM WSW of RWY']
#
#    IDENT    dateonly timeonly               DATE CALLSIGN  POD PRIMARYCODE  \
# 13   RWY   12/8/2018    23:21  2018-12-08T23:21Z    N43RQ  DEN         UAS
# 14   RWY  12/13/2018     0:44  2018-12-13T00:44Z   N6969M  DEN         UAS
# 28   RWY  11/11/2020     3:01  2020-11-11T03:01Z      NaN  DEN         UAS
# 29   RWY  11/16/2020    16:57  2020-11-16T16:57Z      NaN  DEN         UAS
# 35   RWY   4/28/2021    21:23  2021-04-28T21:23Z      NaN  DEN         UAS
#
#    SECONDARYCODES  ... ACALTITUDE.CEDAR  ACHEADING.CEDAR  \
# 13            NaN  ...              NaN              NaN
# 14            NaN  ...              NaN              NaN
# 28            NaN  ...              NaN              NaN
# 29          OTHER  ...              NaN              NaN
# 35            NaN  ...              NaN              NaN
#
#    RELATIVECLOCKPOSITION.CEDAR UASLONG.CEDAR UASLAT.CEDAR SUMMARY.CEDAR  \
# 13                         NaN           NaN          NaN           NaN
# 14                         NaN           NaN          NaN           NaN
# 28                         NaN           NaN          NaN           NaN
# 29                         NaN           NaN          NaN           NaN
# 35                         NaN           NaN          NaN           NaN
#
#    QAFINDINGS.CEDAR LONGITUDE LATITUDE NAME_TXT
# 13              NaN       NaN      NaN      NaN
# 14              NaN       NaN      NaN      NaN
# 28              NaN       NaN      NaN      NaN
# 29              NaN       NaN      NaN      NaN
# 35              NaN       NaN      NaN      NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Save the runways in new csv file

# %%
rwy.to_csv('non-std_uasLoc_runways.csv', index = False)
