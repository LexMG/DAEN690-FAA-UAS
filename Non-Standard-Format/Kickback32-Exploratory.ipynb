# %% [markdown]
# ## This notebook explores 32 records that were kicked back from Lex's R code.
# ### The output of this notebook is:
# #### 1.32 Lat/Long calculated for FAA Airport Identifier

# %%
# Import Libraries
import pandas as pd
import numpy as np
import geopy
from geopy.distance import geodesic

# %%
# Read in the csv file
nonstd = pd.read_csv('C:/Users/Olga/Desktop/GMU/DAEN690/LEGO/Olga_All_Points_Non-Standard_32OUTOF412.csv')
nonstd = nonstd.drop(['IDENT'], 1)
nonstd
# Out:
#                                               REMARKS    dateonly timeonly  \
# 0   Reported observing a uas while at 3,500 feet, ...   2/12/2018     5:15
# 1   Reported observing a uas with red and green li...   2/19/2018    12:05
# 2   EJA262, F2TH, 2 NM E of JYO, Ebound, 2000 feet...    3/1/2018     9:53
# 3   At approximately 1112Z,SAA209, A333, 16 NM S o...   3/26/2018    16:30
# 4   Reported sighting a 10 inch red and silver squ...   4/11/2018    21:09
# 5   Reported observing a black and orange uas oper...   4/18/2018     1:20
# 6   Reported observing a black and white uas opera...    5/4/2018    17:25
# 7   Reported sighting a white uas 500 feet below, ...    5/6/2018    21:20
# 8   Reported sighting a uas at 9,000 feet, 15 NM E...    5/9/2018    22:29
# 9   Reported observing one red uas operating at 1,...   5/11/2018    16:52
# 10  Reported observing a uas operating at 3,000 fe...   5/11/2018    21:25
# 11  Reported observing a rotorcraft uas while NE b...   5/25/2018    22:17
# 12  Fairfax County PDcallthe NCRCC (LEO line) to r...    6/8/2018    11:11
# 13  Reported sighting a Quad-copter uas operating ...   6/12/2018    21:39
# 14  Reported observing a white uas operating off o...   6/15/2018     6:13
# 15  Reported observing a uas 500 feet off of the r...   6/15/2018     6:55
# 16  Reported observing a small dark uas hoveringat...   6/16/2018     7:41
# 17  Reported observing a large uas 300 feet below ...   7/15/2018     8:55
# 18  Reported a drone approximately 4 NM E of IAD a...   8/13/2018     1:31
# 19  Reported observing a red uas at 2,500 feet, 2 ...   8/20/2018     5:03
# 20  Reported sighting a uas operating 500 feet abo...    9/3/2018     1:21
# 21  DCA-2: PCT relayed for DAA ATCT that DAA sees ...  10/16/2018    23:22
# 22  DCA-3.Pilot reported uas at 600 feet on the RY...  10/18/2018    22:18
# 23  Aircraft heading Nbound reported a small drone...  11/14/2018    19:02
# 24  Aircraft reporteda 4 rotor uas whileNE boundat...   2/14/2019    23:43
# 25  Black and White uas 200 feet above aircraft wh...    3/4/2019     1:27
# 26  FRZ uas: uas operations in the vicinity of Vie...   3/24/2019    22:30
# 27  uas, 4 NM N of IAD, Nbound at 4,000'. PCT reac...   4/22/2019     0:50
# 28  FBI detected a Mavic Pro at Breeze Place and M...   9/25/2019    13:02
# 29  A concerned citizen reported two large uas ove...    2/3/2020     1:20
# 30  Aircraft (VM374) observed a uas while E bound ...   5/23/2020    22:22
# 31  N347PD, CJ4, observed a uas 1/2 NM W of ANP at...   9/21/2020    16:22
#
#                  DATE CALLSIGN    POD  PRIMARYCODE          SECONDARYCODES  \
# 0   2018-02-12T05:15Z   N169ME    DEN          UAS                     NaN
# 1   2018-02-19T12:05Z   N449ND    DEN          UAS                     NaN
# 2   2018-03-01T09:53Z   EJA262  NCRCC          UAS                     MOR
# 3   2018-03-26T16:30Z   SAA209  NCRCC          UAS       NOTIFICATION-LATE
# 4   2018-04-11T21:09Z    N14KB    DEN          UAS                     NaN
# 5   2018-04-18T01:20Z    SIL64    DEN          UAS                     NaN
# 6   2018-05-04T17:25Z  JIA5022    DEN          UAS                     NaN
# 7   2018-05-06T21:20Z  ENY4006    DEN          UAS                     NaN
# 8   2018-05-09T22:29Z    SLAM1    DEN          UAS                     NaN
# 9   2018-05-11T16:52Z  JBU2802    DEN          UAS                     NaN
# 10  2018-05-11T21:25Z  EDV3992    DEN          UAS                     NaN
# 11  2018-05-25T22:17Z  DAL2068    DEN          UAS                     NaN
# 12  2018-06-08T11:11Z      NaN  NCRCC          UAS                     NaN
# 13  2018-06-12T21:39Z  RPA5888    DEN          UAS                     NaN
# 14  2018-06-15T06:13Z  EDV3435    DEN          UAS                     NaN
# 15  2018-06-15T06:55Z   N340ST    DEN          UAS                     NaN
# 16  2018-06-16T07:41Z   N101GN    DEN          UAS                     NaN
# 17  2018-07-15T08:55Z   AAL163    DEN          UAS                     NaN
# 18  2018-08-13T01:31Z   UAL914  NCRCC          UAS                     NaN
# 19  2018-08-20T05:03Z  RPA6124    DEN          UAS                     NaN
# 20  2018-09-03T01:21Z   AAL178    DEN          UAS                     NaN
# 21  2018-10-16T23:22Z      NaN  NCRCC  TOI-NCR FRZ         PAGED, TOI, UAS
# 22  2018-10-18T22:18Z   CNS333  NCRCC          UAS  MOR, TOI, TOI-NCR SFRA
# 23  2018-11-14T19:02Z  DAL1287  NCRCC          UAS                     NaN
# 24  2019-02-14T23:43Z  SKW3759    DEN          UAS                     NaN
# 25  2019-03-04T01:27Z  RPA5932    DEN          UAS                     NaN
# 26  2019-03-24T22:30Z      NaN  NCRCC          UAS                     NaN
# 27  2019-04-22T00:50Z   JZA172  NCRCC          UAS              MOR, PAGED
# 28  2019-09-25T13:02Z      NaN  JATOC          UAS             TOI-UAS-TFR
# 29  2020-02-03T01:20Z      NaN    DEN          UAS                     NaN
# 30  2020-05-23T22:22Z    VM374  NCRCC          UAS                     NaN
# 31  2020-09-21T16:22Z      NaN  NCRCC          UAS                     NaN
#
#    REPORTINGFACILITY  MORID.CEDAR  ...  ACALTITUDE.CEDAR  ACHEADING.CEDAR  \
# 0                P50          NaN  ...               NaN              NaN
# 1                F11          NaN  ...               NaN              NaN
# 2                PCT          NaN  ...               NaN              NaN
# 3                PCT          NaN  ...               NaN              NaN
# 4                C90          NaN  ...               NaN              NaN
# 5                ZMA          NaN  ...               NaN              NaN
# 6                N90          NaN  ...               NaN              NaN
# 7                C90          NaN  ...               NaN              NaN
# 8                Y90          NaN  ...               NaN              NaN
# 9                N90          NaN  ...               NaN              NaN
# 10               N90          NaN  ...               NaN              NaN
# 11               N90          NaN  ...               NaN              NaN
# 12              USCG          NaN  ...               NaN              NaN
# 13               N90          NaN  ...               NaN              NaN
# 14               N90          NaN  ...               NaN              NaN
# 15               D10          NaN  ...               NaN              NaN
# 16               C90          NaN  ...               NaN              NaN
# 17               SCT          NaN  ...               NaN              NaN
# 18               PCT          NaN  ...               NaN              NaN
# 19               N90          NaN  ...               NaN              NaN
# 20               N90          NaN  ...               NaN              NaN
# 21               PCT          NaN  ...               NaN              NaN
# 22             NCRCC          NaN  ...               NaN              NaN
# 23               PCT          NaN  ...               NaN              NaN
# 24               N90          NaN  ...               NaN              NaN
# 25               N90          NaN  ...               NaN              NaN
# 26             NCRCC          NaN  ...               NaN              NaN
# 27               PCT          NaN  ...               NaN              NaN
# 28               FBI          NaN  ...               NaN              NaN
# 29               WOC          NaN  ...               NaN              NaN
# 30               PCT          NaN  ...               NaN              NaN
# 31               PCT          NaN  ...               NaN              NaN
#
#     RELATIVECLOCKPOSITION.CEDAR  UASLONG.CEDAR  UASLAT.CEDAR  SUMMARY.CEDAR  \
# 0                           NaN            NaN           NaN            NaN
# 1                           NaN            NaN           NaN            NaN
# 2                           NaN            NaN           NaN            NaN
# 3                           NaN            NaN           NaN            NaN
# 4                           NaN            NaN           NaN            NaN
# 5                           NaN            NaN           NaN            NaN
# 6                           NaN            NaN           NaN            NaN
# 7                           NaN            NaN           NaN            NaN
# 8                           NaN            NaN           NaN            NaN
# 9                           NaN            NaN           NaN            NaN
# 10                          NaN            NaN           NaN            NaN
# 11                          NaN            NaN           NaN            NaN
# 12                          NaN            NaN           NaN            NaN
# 13                          NaN            NaN           NaN            NaN
# 14                          NaN            NaN           NaN            NaN
# 15                          NaN            NaN           NaN            NaN
# 16                          NaN            NaN           NaN            NaN
# 17                          NaN            NaN           NaN            NaN
# 18                          NaN            NaN           NaN            NaN
# 19                          NaN            NaN           NaN            NaN
# 20                          NaN            NaN           NaN            NaN
# 21                          NaN            NaN           NaN            NaN
# 22                          NaN            NaN           NaN            NaN
# 23                          NaN            NaN           NaN            NaN
# 24                          NaN            NaN           NaN            NaN
# 25                          NaN            NaN           NaN            NaN
# 26                          NaN            NaN           NaN            NaN
# 27                          NaN            NaN           NaN            NaN
# 28                          NaN            NaN           NaN            NaN
# 29                          NaN            NaN           NaN            NaN
# 30                          NaN            NaN           NaN            NaN
# 31                          NaN            NaN           NaN            NaN
#
#     QAFINDINGS.CEDAR  DATASET       UASLOCATION  RWYLOCATION
# 0                NaN  AIRPORT    3 NM NE of DVT          NaN
# 1                NaN  AIRPORT  17 NM ESE of ORL          NaN
# 2                NaN  AIRPORT     2 NM E of JYO          NaN
# 3                NaN  AIRPORT    16 NM S of IAD          NaN
# 4                NaN  AIRPORT    10 NM E of MDW          NaN
# 5                NaN  AIRPORT    5 NM SW of FLL          NaN
# 6                NaN  AIRPORT   13 NM SW of LGA          NaN
# 7                NaN  AIRPORT    19 NM E of ORD          NaN
# 8                NaN  AIRPORT  15 NM ESE of BDL          NaN
# 9                NaN  AIRPORT    1 NM SE of JFK          NaN
# 10               NaN  AIRPORT    5 NM NE of LGA          NaN
# 11               NaN  AIRPORT   20 NM SE of JFK          NaN
# 12               NaN  AIRPORT     2 NM S of IAD          NaN
# 13               NaN  AIRPORT     5 NM W of LGA          NaN
# 14               NaN  AIRPORT   15 NM SW of LGA          NaN
# 15               NaN  AIRPORT     5 NM S of AFW          NaN
# 16               NaN  AIRPORT    8 NM SW of MDW          NaN
# 17               NaN  AIRPORT    25 NM E of LAX          NaN
# 18               NaN  AIRPORT     4 NM E of IAD          NaN
# 19               NaN  AIRPORT     2 NM S of LGA          NaN
# 20               NaN  AIRPORT    3 NM SE of JFK          NaN
# 21               NaN  AIRPORT     2 NM E of DAA          NaN
# 22               NaN  AIRPORT     1 NM S of IAD          NaN
# 23               NaN  AIRPORT    10 NM S of DAA          NaN
# 24               NaN  AIRPORT     6 NM E of LGA          NaN
# 25               NaN  AIRPORT    4 nm NE of LGA          NaN
# 26               NaN  AIRPORT    5 NM NW of DCA          NaN
# 27               NaN  AIRPORT     4 NM N of IAD          NaN
# 28               NaN  AIRPORT    .8 nm S of JFK          NaN
# 29               NaN  AIRPORT     5 NM W of SUX          NaN
# 30               NaN  AIRPORT     5 NM S of IAD          NaN
# 31               NaN  AIRPORT    .5 NM W of ANP          NaN
#
# [32 rows x 27 columns]

# %%
# Extract IDENTs
uas_loc = nonstd['UASLOCATION'].tolist()
uas_airport = []

for i in range(len(uas_loc)):
    airport = uas_loc[i].split(' ')[-1]
    
    if len(airport) <= 4:
        uas_airport.append(airport)
    else:
        trim_air = airport[-3:]
        uas_airport.append(trim_air)
        
uas_airport_df = pd.DataFrame()
uas_airport_df['IDENT'] = uas_airport
uas_airport_df
# Out:
#    IDENT
# 0    DVT
# 1    ORL
# 2    JYO
# 3    IAD
# 4    MDW
# 5    FLL
# 6    LGA
# 7    ORD
# 8    BDL
# 9    JFK
# 10   LGA
# 11   JFK
# 12   IAD
# 13   LGA
# 14   LGA
# 15   AFW
# 16   MDW
# 17   LAX
# 18   IAD
# 19   LGA
# 20   JFK
# 21   DAA
# 22   IAD
# 23   DAA
# 24   LGA
# 25   LGA
# 26   DCA
# 27   IAD
# 28   JFK
# 29   SUX
# 30   IAD
# 31   ANP

# %%
# Read in the airports dataset
airports = pd.read_csv('C:/Users/Olga/Desktop/GMU/DAEN690/LEGO/airports_cleaned.csv')

# %%
# Merge IDENTs with airports dataset
uas_air_loc= pd.merge(uas_airport_df, airports, on='IDENT', how='left')
uas_air_loc
# Out:
#    IDENT                                    NAME   LATITUDE   LONGITUDE  \
# 0    DVT                     Phoenix Deer Valley  33.688306 -112.082556
# 1    ORL                                    Exec  28.545462  -81.332930
# 2    JYO                           Leesburg Exec  39.077972  -77.557500
# 3    IAD                  Washington Dulles Intl  38.947444  -77.459944
# 4    MDW                     Chicago Midway Intl  41.785972  -87.752417
# 5    FLL          Fort Lauderdale/Hollywood Intl  26.071667  -80.149694
# 6    LGA                               Laguardia  40.777250  -73.872611
# 7    ORD                     Chicago O'hare Intl  41.976629  -87.907253
# 8    BDL                            Bradley Intl  41.939032  -72.684316
# 9    JFK                     John F Kennedy Intl  40.639928  -73.778693
# 10   LGA                               Laguardia  40.777250  -73.872611
# 11   JFK                     John F Kennedy Intl  40.639928  -73.778693
# 12   IAD                  Washington Dulles Intl  38.947444  -77.459944
# 13   LGA                               Laguardia  40.777250  -73.872611
# 14   LGA                               Laguardia  40.777250  -73.872611
# 15   AFW                     Fort Worth Alliance  32.990386  -97.319441
# 16   MDW                     Chicago Midway Intl  41.785972  -87.752417
# 17   LAX                        Los Angeles Intl  33.942496 -118.408049
# 18   IAD                  Washington Dulles Intl  38.947444  -77.459944
# 19   LGA                               Laguardia  40.777250  -73.872611
# 20   JFK                     John F Kennedy Intl  40.639928  -73.778693
# 21   DAA                             Davison AAF  38.714923  -77.180895
# 22   IAD                  Washington Dulles Intl  38.947444  -77.459944
# 23   DAA                             Davison AAF  38.714923  -77.180895
# 24   LGA                               Laguardia  40.777250  -73.872611
# 25   LGA                               Laguardia  40.777250  -73.872611
# 26   DCA            Ronald Reagan Washington Ntl  38.851444  -77.037722
# 27   IAD                  Washington Dulles Intl  38.947444  -77.459944
# 28   JFK                     John F Kennedy Intl  40.639928  -73.778693
# 29   SUX  Sioux Gateway/Brig General Bud Day Fld  42.401309  -96.384418
# 30   IAD                  Washington Dulles Intl  38.947444  -77.459944
# 31   ANP                                     Lee  38.942878  -76.568399
#
#    ICAO_ID
# 0     KDVT
# 1     KORL
# 2     KJYO
# 3     KIAD
# 4     KMDW
# 5     KFLL
# 6     KLGA
# 7     KORD
# 8     KBDL
# 9     KJFK
# 10    KLGA
# 11    KJFK
# 12    KIAD
# 13    KLGA
# 14    KLGA
# 15    KAFW
# 16    KMDW
# 17    KLAX
# 18    KIAD
# 19    KLGA
# 20    KJFK
# 21    KDAA
# 22    KIAD
# 23    KDAA
# 24    KLGA
# 25    KLGA
# 26    KDCA
# 27    KIAD
# 28    KJFK
# 29    KSUX
# 30    KIAD
# 31    KANP

# %%
# Append needed columns
add_col = nonstd['REMARKS'].tolist()
uas_air_loc['REMARKS'] = add_col
add_col1 = nonstd['UASLOCATION'].tolist()
uas_air_loc['UASLOCATION'] = add_col1
uas_air_loc
# Out:
#    IDENT                                    NAME   LATITUDE   LONGITUDE  \
# 0    DVT                     Phoenix Deer Valley  33.688306 -112.082556
# 1    ORL                                    Exec  28.545462  -81.332930
# 2    JYO                           Leesburg Exec  39.077972  -77.557500
# 3    IAD                  Washington Dulles Intl  38.947444  -77.459944
# 4    MDW                     Chicago Midway Intl  41.785972  -87.752417
# 5    FLL          Fort Lauderdale/Hollywood Intl  26.071667  -80.149694
# 6    LGA                               Laguardia  40.777250  -73.872611
# 7    ORD                     Chicago O'hare Intl  41.976629  -87.907253
# 8    BDL                            Bradley Intl  41.939032  -72.684316
# 9    JFK                     John F Kennedy Intl  40.639928  -73.778693
# 10   LGA                               Laguardia  40.777250  -73.872611
# 11   JFK                     John F Kennedy Intl  40.639928  -73.778693
# 12   IAD                  Washington Dulles Intl  38.947444  -77.459944
# 13   LGA                               Laguardia  40.777250  -73.872611
# 14   LGA                               Laguardia  40.777250  -73.872611
# 15   AFW                     Fort Worth Alliance  32.990386  -97.319441
# 16   MDW                     Chicago Midway Intl  41.785972  -87.752417
# 17   LAX                        Los Angeles Intl  33.942496 -118.408049
# 18   IAD                  Washington Dulles Intl  38.947444  -77.459944
# 19   LGA                               Laguardia  40.777250  -73.872611
# 20   JFK                     John F Kennedy Intl  40.639928  -73.778693
# 21   DAA                             Davison AAF  38.714923  -77.180895
# 22   IAD                  Washington Dulles Intl  38.947444  -77.459944
# 23   DAA                             Davison AAF  38.714923  -77.180895
# 24   LGA                               Laguardia  40.777250  -73.872611
# 25   LGA                               Laguardia  40.777250  -73.872611
# 26   DCA            Ronald Reagan Washington Ntl  38.851444  -77.037722
# 27   IAD                  Washington Dulles Intl  38.947444  -77.459944
# 28   JFK                     John F Kennedy Intl  40.639928  -73.778693
# 29   SUX  Sioux Gateway/Brig General Bud Day Fld  42.401309  -96.384418
# 30   IAD                  Washington Dulles Intl  38.947444  -77.459944
# 31   ANP                                     Lee  38.942878  -76.568399
#
#    ICAO_ID                                            REMARKS  \
# 0     KDVT  Reported observing a uas while at 3,500 feet, ...
# 1     KORL  Reported observing a uas with red and green li...
# 2     KJYO  EJA262, F2TH, 2 NM E of JYO, Ebound, 2000 feet...
# 3     KIAD  At approximately 1112Z,SAA209, A333, 16 NM S o...
# 4     KMDW  Reported sighting a 10 inch red and silver squ...
# 5     KFLL  Reported observing a black and orange uas oper...
# 6     KLGA  Reported observing a black and white uas opera...
# 7     KORD  Reported sighting a white uas 500 feet below, ...
# 8     KBDL  Reported sighting a uas at 9,000 feet, 15 NM E...
# 9     KJFK  Reported observing one red uas operating at 1,...
# 10    KLGA  Reported observing a uas operating at 3,000 fe...
# 11    KJFK  Reported observing a rotorcraft uas while NE b...
# 12    KIAD  Fairfax County PDcallthe NCRCC (LEO line) to r...
# 13    KLGA  Reported sighting a Quad-copter uas operating ...
# 14    KLGA  Reported observing a white uas operating off o...
# 15    KAFW  Reported observing a uas 500 feet off of the r...
# 16    KMDW  Reported observing a small dark uas hoveringat...
# 17    KLAX  Reported observing a large uas 300 feet below ...
# 18    KIAD  Reported a drone approximately 4 NM E of IAD a...
# 19    KLGA  Reported observing a red uas at 2,500 feet, 2 ...
# 20    KJFK  Reported sighting a uas operating 500 feet abo...
# 21    KDAA  DCA-2: PCT relayed for DAA ATCT that DAA sees ...
# 22    KIAD  DCA-3.Pilot reported uas at 600 feet on the RY...
# 23    KDAA  Aircraft heading Nbound reported a small drone...
# 24    KLGA  Aircraft reporteda 4 rotor uas whileNE boundat...
# 25    KLGA  Black and White uas 200 feet above aircraft wh...
# 26    KDCA  FRZ uas: uas operations in the vicinity of Vie...
# 27    KIAD  uas, 4 NM N of IAD, Nbound at 4,000'. PCT reac...
# 28    KJFK  FBI detected a Mavic Pro at Breeze Place and M...
# 29    KSUX  A concerned citizen reported two large uas ove...
# 30    KIAD  Aircraft (VM374) observed a uas while E bound ...
# 31    KANP  N347PD, CJ4, observed a uas 1/2 NM W of ANP at...
#
#          UASLOCATION
# 0     3 NM NE of DVT
# 1   17 NM ESE of ORL
# 2      2 NM E of JYO
# 3     16 NM S of IAD
# 4     10 NM E of MDW
# 5     5 NM SW of FLL
# 6    13 NM SW of LGA
# 7     19 NM E of ORD
# 8   15 NM ESE of BDL
# 9     1 NM SE of JFK
# 10    5 NM NE of LGA
# 11   20 NM SE of JFK
# 12     2 NM S of IAD
# 13     5 NM W of LGA
# 14   15 NM SW of LGA
# 15     5 NM S of AFW
# 16    8 NM SW of MDW
# 17    25 NM E of LAX
# 18     4 NM E of IAD
# 19     2 NM S of LGA
# 20    3 NM SE of JFK
# 21     2 NM E of DAA
# 22     1 NM S of IAD
# 23    10 NM S of DAA
# 24     6 NM E of LGA
# 25    4 nm NE of LGA
# 26    5 NM NW of DCA
# 27     4 NM N of IAD
# 28    .8 nm S of JFK
# 29     5 NM W of SUX
# 30     5 NM S of IAD
# 31    .5 NM W of ANP

# %%
# Create dictionary for bearing abbreviations and their degrees
bearing_deg = {
    'N' : 0,
    'NNE' : 23,
    'NE' : 45,
    'ENE' : 68,
    'E' : 90,
    'ESE' : 113,
    'SE' : 135,
    'SSE' : 158,
    'S' : 180,
    'SSW' : 203,
    'SW' : 225,
    'WSW' : 248,
    'W' : 270,
    'WNW' : 293,
    'NW' : 315,
    'NNW' : 338
}

# Separate Distances and bearings into two columns
uas_loc = uas_air_loc['UASLOCATION']
distances = []
bearings = []

for i in range(len(uas_loc)):
    split = uas_loc[i].split(' ')[0:3]
    
    if 'NM' in split[0]: #if there is no space between the distance and NM (i.e. 3NM)
        distance_nm = split[0][0:len(split[0]) - 2]
        bearing_abrev = split[1].replace('of', '')
        
    else: 
        distance_nm = split[0]
        bearing_abrev = split[2].replace('of', '')
    
    distances.append(distance_nm[0:])
    bearings.append(bearing_abrev)

# Create DataFrame to store UAS Location Information
new_df = pd.DataFrame(uas_air_loc['REMARKS'])
new_df['UAS_LOC'] = uas_air_loc['UASLOCATION']
new_df['IDENT'] = uas_air_loc['IDENT']
new_df['Distance'] = distances
new_df['Bearing'] = bearings

new_df
# Out:
#                                               REMARKS           UAS_LOC IDENT  \
# 0   Reported observing a uas while at 3,500 feet, ...    3 NM NE of DVT   DVT
# 1   Reported observing a uas with red and green li...  17 NM ESE of ORL   ORL
# 2   EJA262, F2TH, 2 NM E of JYO, Ebound, 2000 feet...     2 NM E of JYO   JYO
# 3   At approximately 1112Z,SAA209, A333, 16 NM S o...    16 NM S of IAD   IAD
# 4   Reported sighting a 10 inch red and silver squ...    10 NM E of MDW   MDW
# 5   Reported observing a black and orange uas oper...    5 NM SW of FLL   FLL
# 6   Reported observing a black and white uas opera...   13 NM SW of LGA   LGA
# 7   Reported sighting a white uas 500 feet below, ...    19 NM E of ORD   ORD
# 8   Reported sighting a uas at 9,000 feet, 15 NM E...  15 NM ESE of BDL   BDL
# 9   Reported observing one red uas operating at 1,...    1 NM SE of JFK   JFK
# 10  Reported observing a uas operating at 3,000 fe...    5 NM NE of LGA   LGA
# 11  Reported observing a rotorcraft uas while NE b...   20 NM SE of JFK   JFK
# 12  Fairfax County PDcallthe NCRCC (LEO line) to r...     2 NM S of IAD   IAD
# 13  Reported sighting a Quad-copter uas operating ...     5 NM W of LGA   LGA
# 14  Reported observing a white uas operating off o...   15 NM SW of LGA   LGA
# 15  Reported observing a uas 500 feet off of the r...     5 NM S of AFW   AFW
# 16  Reported observing a small dark uas hoveringat...    8 NM SW of MDW   MDW
# 17  Reported observing a large uas 300 feet below ...    25 NM E of LAX   LAX
# 18  Reported a drone approximately 4 NM E of IAD a...     4 NM E of IAD   IAD
# 19  Reported observing a red uas at 2,500 feet, 2 ...     2 NM S of LGA   LGA
# 20  Reported sighting a uas operating 500 feet abo...    3 NM SE of JFK   JFK
# 21  DCA-2: PCT relayed for DAA ATCT that DAA sees ...     2 NM E of DAA   DAA
# 22  DCA-3.Pilot reported uas at 600 feet on the RY...     1 NM S of IAD   IAD
# 23  Aircraft heading Nbound reported a small drone...    10 NM S of DAA   DAA
# 24  Aircraft reporteda 4 rotor uas whileNE boundat...     6 NM E of LGA   LGA
# 25  Black and White uas 200 feet above aircraft wh...    4 nm NE of LGA   LGA
# 26  FRZ uas: uas operations in the vicinity of Vie...    5 NM NW of DCA   DCA
# 27  uas, 4 NM N of IAD, Nbound at 4,000'. PCT reac...     4 NM N of IAD   IAD
# 28  FBI detected a Mavic Pro at Breeze Place and M...    .8 nm S of JFK   JFK
# 29  A concerned citizen reported two large uas ove...     5 NM W of SUX   SUX
# 30  Aircraft (VM374) observed a uas while E bound ...     5 NM S of IAD   IAD
# 31  N347PD, CJ4, observed a uas 1/2 NM W of ANP at...    .5 NM W of ANP   ANP
#
#    Distance Bearing
# 0         3      NE
# 1        17     ESE
# 2         2       E
# 3        16       S
# 4        10       E
# 5         5      SW
# 6        13      SW
# 7        19       E
# 8        15     ESE
# 9         1      SE
# 10        5      NE
# 11       20      SE
# 12        2       S
# 13        5       W
# 14       15      SW
# 15        5       S
# 16        8      SW
# 17       25       E
# 18        4       E
# 19        2       S
# 20        3      SE
# 21        2       E
# 22        1       S
# 23       10       S
# 24        6       E
# 25        4      NE
# 26        5      NW
# 27        4       N
# 28       .8       S
# 29        5       W
# 30        5       S
# 31       .5       W

# %%
# Convert distances from NM to KM and bearings to degrees
new_df['Distance'] = pd.to_numeric(new_df['Distance'],errors = 'coerce')
dist_kilo = []

for i in range(len(new_df)):
    distanceKilo = new_df['Distance'][i] * 1.852 # converting NM to kilometers
    dist_kilo.append(distanceKilo)

bearDegree = pd.DataFrame(new_df['Bearing'])
bearDegree = bearDegree.replace({'Bearing': bearing_deg})

new_df['Distance_Kilometers'] = dist_kilo
new_df['Bearing_Degrees'] = bearDegree
new_df['Airport_Latitude'] = uas_air_loc['LATITUDE']
new_df['Airport_Longitude'] = uas_air_loc['LONGITUDE']
new_df
# Out:
#                                               REMARKS           UAS_LOC IDENT  \
# 0   Reported observing a uas while at 3,500 feet, ...    3 NM NE of DVT   DVT
# 1   Reported observing a uas with red and green li...  17 NM ESE of ORL   ORL
# 2   EJA262, F2TH, 2 NM E of JYO, Ebound, 2000 feet...     2 NM E of JYO   JYO
# 3   At approximately 1112Z,SAA209, A333, 16 NM S o...    16 NM S of IAD   IAD
# 4   Reported sighting a 10 inch red and silver squ...    10 NM E of MDW   MDW
# 5   Reported observing a black and orange uas oper...    5 NM SW of FLL   FLL
# 6   Reported observing a black and white uas opera...   13 NM SW of LGA   LGA
# 7   Reported sighting a white uas 500 feet below, ...    19 NM E of ORD   ORD
# 8   Reported sighting a uas at 9,000 feet, 15 NM E...  15 NM ESE of BDL   BDL
# 9   Reported observing one red uas operating at 1,...    1 NM SE of JFK   JFK
# 10  Reported observing a uas operating at 3,000 fe...    5 NM NE of LGA   LGA
# 11  Reported observing a rotorcraft uas while NE b...   20 NM SE of JFK   JFK
# 12  Fairfax County PDcallthe NCRCC (LEO line) to r...     2 NM S of IAD   IAD
# 13  Reported sighting a Quad-copter uas operating ...     5 NM W of LGA   LGA
# 14  Reported observing a white uas operating off o...   15 NM SW of LGA   LGA
# 15  Reported observing a uas 500 feet off of the r...     5 NM S of AFW   AFW
# 16  Reported observing a small dark uas hoveringat...    8 NM SW of MDW   MDW
# 17  Reported observing a large uas 300 feet below ...    25 NM E of LAX   LAX
# 18  Reported a drone approximately 4 NM E of IAD a...     4 NM E of IAD   IAD
# 19  Reported observing a red uas at 2,500 feet, 2 ...     2 NM S of LGA   LGA
# 20  Reported sighting a uas operating 500 feet abo...    3 NM SE of JFK   JFK
# 21  DCA-2: PCT relayed for DAA ATCT that DAA sees ...     2 NM E of DAA   DAA
# 22  DCA-3.Pilot reported uas at 600 feet on the RY...     1 NM S of IAD   IAD
# 23  Aircraft heading Nbound reported a small drone...    10 NM S of DAA   DAA
# 24  Aircraft reporteda 4 rotor uas whileNE boundat...     6 NM E of LGA   LGA
# 25  Black and White uas 200 feet above aircraft wh...    4 nm NE of LGA   LGA
# 26  FRZ uas: uas operations in the vicinity of Vie...    5 NM NW of DCA   DCA
# 27  uas, 4 NM N of IAD, Nbound at 4,000'. PCT reac...     4 NM N of IAD   IAD
# 28  FBI detected a Mavic Pro at Breeze Place and M...    .8 nm S of JFK   JFK
# 29  A concerned citizen reported two large uas ove...     5 NM W of SUX   SUX
# 30  Aircraft (VM374) observed a uas while E bound ...     5 NM S of IAD   IAD
# 31  N347PD, CJ4, observed a uas 1/2 NM W of ANP at...    .5 NM W of ANP   ANP
#
#     Distance Bearing  Distance_Kilometers  Bearing_Degrees  Airport_Latitude  \
# 0        3.0      NE               5.5560               45         33.688306
# 1       17.0     ESE              31.4840              113         28.545462
# 2        2.0       E               3.7040               90         39.077972
# 3       16.0       S              29.6320              180         38.947444
# 4       10.0       E              18.5200               90         41.785972
# 5        5.0      SW               9.2600              225         26.071667
# 6       13.0      SW              24.0760              225         40.777250
# 7       19.0       E              35.1880               90         41.976629
# 8       15.0     ESE              27.7800              113         41.939032
# 9        1.0      SE               1.8520              135         40.639928
# 10       5.0      NE               9.2600               45         40.777250
# 11      20.0      SE              37.0400              135         40.639928
# 12       2.0       S               3.7040              180         38.947444
# 13       5.0       W               9.2600              270         40.777250
# 14      15.0      SW              27.7800              225         40.777250
# 15       5.0       S               9.2600              180         32.990386
# 16       8.0      SW              14.8160              225         41.785972
# 17      25.0       E              46.3000               90         33.942496
# 18       4.0       E               7.4080               90         38.947444
# 19       2.0       S               3.7040              180         40.777250
# 20       3.0      SE               5.5560              135         40.639928
# 21       2.0       E               3.7040               90         38.714923
# 22       1.0       S               1.8520              180         38.947444
# 23      10.0       S              18.5200              180         38.714923
# 24       6.0       E              11.1120               90         40.777250
# 25       4.0      NE               7.4080               45         40.777250
# 26       5.0      NW               9.2600              315         38.851444
# 27       4.0       N               7.4080                0         38.947444
# 28       0.8       S               1.4816              180         40.639928
# 29       5.0       W               9.2600              270         42.401309
# 30       5.0       S               9.2600              180         38.947444
# 31       0.5       W               0.9260              270         38.942878
#
#     Airport_Longitude
# 0         -112.082556
# 1          -81.332930
# 2          -77.557500
# 3          -77.459944
# 4          -87.752417
# 5          -80.149694
# 6          -73.872611
# 7          -87.907253
# 8          -72.684316
# 9          -73.778693
# 10         -73.872611
# 11         -73.778693
# 12         -77.459944
# 13         -73.872611
# 14         -73.872611
# 15         -97.319441
# 16         -87.752417
# 17        -118.408049
# 18         -77.459944
# 19         -73.872611
# 20         -73.778693
# 21         -77.180895
# 22         -77.459944
# 23         -77.180895
# 24         -73.872611
# 25         -73.872611
# 26         -77.037722
# 27         -77.459944
# 28         -73.778693
# 29         -96.384418
# 30         -77.459944
# 31         -76.568399

# %%
# Merge, drop and rename columns
new_df2 = pd.merge(new_df, airports, on='IDENT', how='left')
new_df2 = new_df2.drop(['Airport_Latitude', 'Airport_Longitude'], 1)
new_df2 = new_df2.rename({'LONGITUDE': 'Airport_Longitude', 'LATITUDE': 'Airport_Latitude'}, axis=1)
new_df2
# Out:
#                                               REMARKS           UAS_LOC IDENT  \
# 0   Reported observing a uas while at 3,500 feet, ...    3 NM NE of DVT   DVT
# 1   Reported observing a uas with red and green li...  17 NM ESE of ORL   ORL
# 2   EJA262, F2TH, 2 NM E of JYO, Ebound, 2000 feet...     2 NM E of JYO   JYO
# 3   At approximately 1112Z,SAA209, A333, 16 NM S o...    16 NM S of IAD   IAD
# 4   Reported sighting a 10 inch red and silver squ...    10 NM E of MDW   MDW
# 5   Reported observing a black and orange uas oper...    5 NM SW of FLL   FLL
# 6   Reported observing a black and white uas opera...   13 NM SW of LGA   LGA
# 7   Reported sighting a white uas 500 feet below, ...    19 NM E of ORD   ORD
# 8   Reported sighting a uas at 9,000 feet, 15 NM E...  15 NM ESE of BDL   BDL
# 9   Reported observing one red uas operating at 1,...    1 NM SE of JFK   JFK
# 10  Reported observing a uas operating at 3,000 fe...    5 NM NE of LGA   LGA
# 11  Reported observing a rotorcraft uas while NE b...   20 NM SE of JFK   JFK
# 12  Fairfax County PDcallthe NCRCC (LEO line) to r...     2 NM S of IAD   IAD
# 13  Reported sighting a Quad-copter uas operating ...     5 NM W of LGA   LGA
# 14  Reported observing a white uas operating off o...   15 NM SW of LGA   LGA
# 15  Reported observing a uas 500 feet off of the r...     5 NM S of AFW   AFW
# 16  Reported observing a small dark uas hoveringat...    8 NM SW of MDW   MDW
# 17  Reported observing a large uas 300 feet below ...    25 NM E of LAX   LAX
# 18  Reported a drone approximately 4 NM E of IAD a...     4 NM E of IAD   IAD
# 19  Reported observing a red uas at 2,500 feet, 2 ...     2 NM S of LGA   LGA
# 20  Reported sighting a uas operating 500 feet abo...    3 NM SE of JFK   JFK
# 21  DCA-2: PCT relayed for DAA ATCT that DAA sees ...     2 NM E of DAA   DAA
# 22  DCA-3.Pilot reported uas at 600 feet on the RY...     1 NM S of IAD   IAD
# 23  Aircraft heading Nbound reported a small drone...    10 NM S of DAA   DAA
# 24  Aircraft reporteda 4 rotor uas whileNE boundat...     6 NM E of LGA   LGA
# 25  Black and White uas 200 feet above aircraft wh...    4 nm NE of LGA   LGA
# 26  FRZ uas: uas operations in the vicinity of Vie...    5 NM NW of DCA   DCA
# 27  uas, 4 NM N of IAD, Nbound at 4,000'. PCT reac...     4 NM N of IAD   IAD
# 28  FBI detected a Mavic Pro at Breeze Place and M...    .8 nm S of JFK   JFK
# 29  A concerned citizen reported two large uas ove...     5 NM W of SUX   SUX
# 30  Aircraft (VM374) observed a uas while E bound ...     5 NM S of IAD   IAD
# 31  N347PD, CJ4, observed a uas 1/2 NM W of ANP at...    .5 NM W of ANP   ANP
#
#     Distance Bearing  Distance_Kilometers  Bearing_Degrees  \
# 0        3.0      NE               5.5560               45
# 1       17.0     ESE              31.4840              113
# 2        2.0       E               3.7040               90
# 3       16.0       S              29.6320              180
# 4       10.0       E              18.5200               90
# 5        5.0      SW               9.2600              225
# 6       13.0      SW              24.0760              225
# 7       19.0       E              35.1880               90
# 8       15.0     ESE              27.7800              113
# 9        1.0      SE               1.8520              135
# 10       5.0      NE               9.2600               45
# 11      20.0      SE              37.0400              135
# 12       2.0       S               3.7040              180
# 13       5.0       W               9.2600              270
# 14      15.0      SW              27.7800              225
# 15       5.0       S               9.2600              180
# 16       8.0      SW              14.8160              225
# 17      25.0       E              46.3000               90
# 18       4.0       E               7.4080               90
# 19       2.0       S               3.7040              180
# 20       3.0      SE               5.5560              135
# 21       2.0       E               3.7040               90
# 22       1.0       S               1.8520              180
# 23      10.0       S              18.5200              180
# 24       6.0       E              11.1120               90
# 25       4.0      NE               7.4080               45
# 26       5.0      NW               9.2600              315
# 27       4.0       N               7.4080                0
# 28       0.8       S               1.4816              180
# 29       5.0       W               9.2600              270
# 30       5.0       S               9.2600              180
# 31       0.5       W               0.9260              270
#
#                                       NAME  Airport_Latitude  \
# 0                      Phoenix Deer Valley         33.688306
# 1                                     Exec         28.545462
# 2                            Leesburg Exec         39.077972
# 3                   Washington Dulles Intl         38.947444
# 4                      Chicago Midway Intl         41.785972
# 5           Fort Lauderdale/Hollywood Intl         26.071667
# 6                                Laguardia         40.777250
# 7                      Chicago O'hare Intl         41.976629
# 8                             Bradley Intl         41.939032
# 9                      John F Kennedy Intl         40.639928
# 10                               Laguardia         40.777250
# 11                     John F Kennedy Intl         40.639928
# 12                  Washington Dulles Intl         38.947444
# 13                               Laguardia         40.777250
# 14                               Laguardia         40.777250
# 15                     Fort Worth Alliance         32.990386
# 16                     Chicago Midway Intl         41.785972
# 17                        Los Angeles Intl         33.942496
# 18                  Washington Dulles Intl         38.947444
# 19                               Laguardia         40.777250
# 20                     John F Kennedy Intl         40.639928
# 21                             Davison AAF         38.714923
# 22                  Washington Dulles Intl         38.947444
# 23                             Davison AAF         38.714923
# 24                               Laguardia         40.777250
# 25                               Laguardia         40.777250
# 26            Ronald Reagan Washington Ntl         38.851444
# 27                  Washington Dulles Intl         38.947444
# 28                     John F Kennedy Intl         40.639928
# 29  Sioux Gateway/Brig General Bud Day Fld         42.401309
# 30                  Washington Dulles Intl         38.947444
# 31                                     Lee         38.942878
#
#     Airport_Longitude ICAO_ID
# 0         -112.082556    KDVT
# 1          -81.332930    KORL
# 2          -77.557500    KJYO
# 3          -77.459944    KIAD
# 4          -87.752417    KMDW
# 5          -80.149694    KFLL
# 6          -73.872611    KLGA
# 7          -87.907253    KORD
# 8          -72.684316    KBDL
# 9          -73.778693    KJFK
# 10         -73.872611    KLGA
# 11         -73.778693    KJFK
# 12         -77.459944    KIAD
# 13         -73.872611    KLGA
# 14         -73.872611    KLGA
# 15         -97.319441    KAFW
# 16         -87.752417    KMDW
# 17        -118.408049    KLAX
# 18         -77.459944    KIAD
# 19         -73.872611    KLGA
# 20         -73.778693    KJFK
# 21         -77.180895    KDAA
# 22         -77.459944    KIAD
# 23         -77.180895    KDAA
# 24         -73.872611    KLGA
# 25         -73.872611    KLGA
# 26         -77.037722    KDCA
# 27         -77.459944    KIAD
# 28         -73.778693    KJFK
# 29         -96.384418    KSUX
# 30         -77.459944    KIAD
# 31         -76.568399    KANP

# %%
# Calculate UAS lat/long
uas_lat = []
uas_long = []

for i in range(len(new_df)):
    lat_airport = pd.to_numeric(new_df2['Airport_Latitude'][i])
    long_airport = pd.to_numeric(new_df2['Airport_Longitude'][i])
    b = pd.to_numeric(new_df['Bearing_Degrees'][i])
    d = pd.to_numeric(new_df['Distance_Kilometers'][i])
    
    origin = geopy.Point(lat_airport, long_airport)
    destination = geodesic(kilometers=d).destination(origin,b)
    
    lat2, lon2, = destination.latitude, destination.longitude
    
    uas_lat.append(lat2)
    uas_long.append(lon2)

# Append UAS Lat/Long information to DataFrame
new_df2['UAS_Latitude'] = uas_lat
new_df2['UAS_Longitude'] = uas_long
new_df2
# Out:
#                                               REMARKS           UAS_LOC IDENT  \
# 0   Reported observing a uas while at 3,500 feet, ...    3 NM NE of DVT   DVT
# 1   Reported observing a uas with red and green li...  17 NM ESE of ORL   ORL
# 2   EJA262, F2TH, 2 NM E of JYO, Ebound, 2000 feet...     2 NM E of JYO   JYO
# 3   At approximately 1112Z,SAA209, A333, 16 NM S o...    16 NM S of IAD   IAD
# 4   Reported sighting a 10 inch red and silver squ...    10 NM E of MDW   MDW
# 5   Reported observing a black and orange uas oper...    5 NM SW of FLL   FLL
# 6   Reported observing a black and white uas opera...   13 NM SW of LGA   LGA
# 7   Reported sighting a white uas 500 feet below, ...    19 NM E of ORD   ORD
# 8   Reported sighting a uas at 9,000 feet, 15 NM E...  15 NM ESE of BDL   BDL
# 9   Reported observing one red uas operating at 1,...    1 NM SE of JFK   JFK
# 10  Reported observing a uas operating at 3,000 fe...    5 NM NE of LGA   LGA
# 11  Reported observing a rotorcraft uas while NE b...   20 NM SE of JFK   JFK
# 12  Fairfax County PDcallthe NCRCC (LEO line) to r...     2 NM S of IAD   IAD
# 13  Reported sighting a Quad-copter uas operating ...     5 NM W of LGA   LGA
# 14  Reported observing a white uas operating off o...   15 NM SW of LGA   LGA
# 15  Reported observing a uas 500 feet off of the r...     5 NM S of AFW   AFW
# 16  Reported observing a small dark uas hoveringat...    8 NM SW of MDW   MDW
# 17  Reported observing a large uas 300 feet below ...    25 NM E of LAX   LAX
# 18  Reported a drone approximately 4 NM E of IAD a...     4 NM E of IAD   IAD
# 19  Reported observing a red uas at 2,500 feet, 2 ...     2 NM S of LGA   LGA
# 20  Reported sighting a uas operating 500 feet abo...    3 NM SE of JFK   JFK
# 21  DCA-2: PCT relayed for DAA ATCT that DAA sees ...     2 NM E of DAA   DAA
# 22  DCA-3.Pilot reported uas at 600 feet on the RY...     1 NM S of IAD   IAD
# 23  Aircraft heading Nbound reported a small drone...    10 NM S of DAA   DAA
# 24  Aircraft reporteda 4 rotor uas whileNE boundat...     6 NM E of LGA   LGA
# 25  Black and White uas 200 feet above aircraft wh...    4 nm NE of LGA   LGA
# 26  FRZ uas: uas operations in the vicinity of Vie...    5 NM NW of DCA   DCA
# 27  uas, 4 NM N of IAD, Nbound at 4,000'. PCT reac...     4 NM N of IAD   IAD
# 28  FBI detected a Mavic Pro at Breeze Place and M...    .8 nm S of JFK   JFK
# 29  A concerned citizen reported two large uas ove...     5 NM W of SUX   SUX
# 30  Aircraft (VM374) observed a uas while E bound ...     5 NM S of IAD   IAD
# 31  N347PD, CJ4, observed a uas 1/2 NM W of ANP at...    .5 NM W of ANP   ANP
#
#     Distance Bearing  Distance_Kilometers  Bearing_Degrees  \
# 0        3.0      NE               5.5560               45
# 1       17.0     ESE              31.4840              113
# 2        2.0       E               3.7040               90
# 3       16.0       S              29.6320              180
# 4       10.0       E              18.5200               90
# 5        5.0      SW               9.2600              225
# 6       13.0      SW              24.0760              225
# 7       19.0       E              35.1880               90
# 8       15.0     ESE              27.7800              113
# 9        1.0      SE               1.8520              135
# 10       5.0      NE               9.2600               45
# 11      20.0      SE              37.0400              135
# 12       2.0       S               3.7040              180
# 13       5.0       W               9.2600              270
# 14      15.0      SW              27.7800              225
# 15       5.0       S               9.2600              180
# 16       8.0      SW              14.8160              225
# 17      25.0       E              46.3000               90
# 18       4.0       E               7.4080               90
# 19       2.0       S               3.7040              180
# 20       3.0      SE               5.5560              135
# 21       2.0       E               3.7040               90
# 22       1.0       S               1.8520              180
# 23      10.0       S              18.5200              180
# 24       6.0       E              11.1120               90
# 25       4.0      NE               7.4080               45
# 26       5.0      NW               9.2600              315
# 27       4.0       N               7.4080                0
# 28       0.8       S               1.4816              180
# 29       5.0       W               9.2600              270
# 30       5.0       S               9.2600              180
# 31       0.5       W               0.9260              270
#
#                                       NAME  Airport_Latitude  \
# 0                      Phoenix Deer Valley         33.688306
# 1                                     Exec         28.545462
# 2                            Leesburg Exec         39.077972
# 3                   Washington Dulles Intl         38.947444
# 4                      Chicago Midway Intl         41.785972
# 5           Fort Lauderdale/Hollywood Intl         26.071667
# 6                                Laguardia         40.777250
# 7                      Chicago O'hare Intl         41.976629
# 8                             Bradley Intl         41.939032
# 9                      John F Kennedy Intl         40.639928
# 10                               Laguardia         40.777250
# 11                     John F Kennedy Intl         40.639928
# 12                  Washington Dulles Intl         38.947444
# 13                               Laguardia         40.777250
# 14                               Laguardia         40.777250
# 15                     Fort Worth Alliance         32.990386
# 16                     Chicago Midway Intl         41.785972
# 17                        Los Angeles Intl         33.942496
# 18                  Washington Dulles Intl         38.947444
# 19                               Laguardia         40.777250
# 20                     John F Kennedy Intl         40.639928
# 21                             Davison AAF         38.714923
# 22                  Washington Dulles Intl         38.947444
# 23                             Davison AAF         38.714923
# 24                               Laguardia         40.777250
# 25                               Laguardia         40.777250
# 26            Ronald Reagan Washington Ntl         38.851444
# 27                  Washington Dulles Intl         38.947444
# 28                     John F Kennedy Intl         40.639928
# 29  Sioux Gateway/Brig General Bud Day Fld         42.401309
# 30                  Washington Dulles Intl         38.947444
# 31                                     Lee         38.942878
#
#     Airport_Longitude ICAO_ID  UAS_Latitude  UAS_Longitude
# 0         -112.082556    KDVT     33.723718    -112.040167
# 1          -81.332930    KORL     28.434140     -81.037097
# 2          -77.557500    KJYO     39.077964     -77.514695
# 3          -77.459944    KIAD     38.680518     -77.459944
# 4          -87.752417    KMDW     41.785756     -87.529628
# 5          -80.149694    KFLL     26.012550     -80.215102
# 6          -73.872611    KLGA     40.623769     -74.073816
# 7          -87.907253    KORD     41.975844     -87.482696
# 8          -72.684316    KBDL     41.840893     -72.376434
# 9          -73.778693    KJFK     40.628134     -73.763214
# 10         -73.872611    KLGA     40.836187     -73.794978
# 11         -73.778693    KJFK     40.403653     -73.470157
# 12         -77.459944    KIAD     38.914079     -77.459944
# 13         -73.872611    KLGA     40.777198     -73.982304
# 14         -73.872611    KLGA     40.600125     -74.104689
# 15         -97.319441    KAFW     32.906890     -97.319441
# 16         -87.752417    KMDW     41.691578     -87.878261
# 17        -118.408049    KLAX     33.941478    -117.907225
# 18         -77.459944    KIAD     38.947413     -77.374491
# 19         -73.872611    KLGA     40.743895     -73.872611
# 20         -73.778693    KJFK     40.604540     -73.732274
# 21         -77.180895    KDAA     38.714915     -77.138307
# 22         -77.459944    KIAD     38.930762     -77.459944
# 23         -77.180895    KDAA     38.548088     -77.180895
# 24         -73.872611    KLGA     40.777175     -73.740980
# 25         -73.872611    KLGA     40.824403     -73.810516
# 26         -77.037722    KDCA     38.910402     -77.113214
# 27         -77.459944    KIAD     39.014174     -77.459944
# 28         -73.778693    KJFK     40.626586     -73.778693
# 29         -96.384418    KSUX     42.401254     -96.496895
# 30         -77.459944    KIAD     38.864031     -77.459944
# 31         -76.568399    KANP     38.942877     -76.579080

# %%
# Export records to csv file
new_df2 = new_df2.drop(['Distance','Bearing','Distance_Kilometers','Bearing_Degrees','ICAO_ID'], 1)
new_df2 = new_df2.rename({'Airport_Longitude': 'Origin_Longitude', 'Airport_Latitude': 'Origin_Latitude'}, axis=1)
new_df2 = pd.merge(new_df2, nonstd, on='REMARKS', how='left')
new_df2.to_csv('COMPLETED-Non-std-32Airports.csv', index = False)
