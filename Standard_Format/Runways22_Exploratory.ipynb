# %% [markdown]
# # Exploring 22 Records Referencing Runways (Kickback from 302 records sent to Lex)
# ***
# ***DAEN690***
#
# ***George Mason University***
#
# ***Author:*** Grace Cox (Team LEGO)
#
# ***Date:*** November 15, 2021
# ***
# `This Jupyter Notebook explores 22 records (of 302 records) that reference runways within the remarks. The process for exploring these records is as follows:`
#
# 1. Drop records with field entries that are null
# 2. Merge remaining records with the airports_runways_linked.csv file, which contains the lat/long coordinates of runways at select airports
# 3. Extract Runway Designator from the Runway Location
# 4. Check if the Runway Designator found within the remark links/matches with one of the runway in the airports_runways_linked.csv dataset
#     a. Those records for which there is no link to the aforementioned supplemental dataset will be moved to the exceptions file, as there is no runway with that specific name at the airport mentioned.
# 5. Link with the airports_cleaned_declination.csv in order to obtain the declination
# 6. Calculate bearing information for runways
# 7. Convert Distance from NM to Kilometers
#     a. If NO DISTANCE information is provided in the remark, the Runway lat/long coordinates are used for the UAS lat/long coordinates
# 8. Calculate UAS latitude/longitude coordinated using geopy
#
# ***
# ### INPUT:
# *Dataframe (read from a .csv file) containing 22 records, of 302 records that did not hit on the initial 'XX NM dir XXX' regular expressions, but do reference a runway.*
#
# ### OUTPUT:
# <font color='red'>**EXCPETIONS FILE**</font>
#
# *Runways (no distance information or no match to airports/runways dataset): 2 records*
#
# <font color='green'>**UAS LATITUDE/LONGITUDE COORDINATE CALCULATED**</font>
#
# *Runway: 20 records*

# %% [markdown]
# ## Import Statements

# %%
# Import Statements
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import chart_studio.plotly as py
import re
import geopy
from geopy.distance import geodesic
from fractions import Fraction

from IPython.display import display, HTML

# %%
rwy22_allrows = pd.read_csv('C:/Users/grace/OneDrive/Desktop/GMU/DAEN690/Grace_All_Points_rwy302_allrows.csv')
rwy22_allrows
# Out:
#     index                                            REMARKS  \
# 0     433  Aircraft reported a uasmaneuvering 300 feet be...
# 1     452  Aircraft reported a black and red four rotor u...
# 2     473  Aircraft reported a shiny uas at same altitude...
# 3     507  Aircraft reported a white 4 rotor uas approxim...
# 4     534  Aircraft reported a uas off the left side at 1...
# 5     544  Aircraft reported a uas hovering at approximat...
# 6     565  Aircraft reported a white and brown quad-copte...
# 7     126  Aircraft observed a black uas while SW bound a...
# 8     205  Aircraft observed a uas while NE bound in a le...
# 9     252  Aircraft observed a uas below while W bound on...
# 10    254  Aircraft observed a white uas at 7,100 feet of...
# 11    272  Aircraft observed a small uas directly below w...
# 12    285  Aircraft observed a quad copter uas off the ri...
# 13    295  Aircraft observed a white uas while S bound at...
# 14    298  1836 Aircraft observed a uas off the right sid...
# 15    299  Aircraft observed a uas on 7 NM final to RWY 0...
# 16    319  Aircraft observed a uas off the right side whi...
# 17    321  Aircraft observed a uas off the left side whil...
# 18    357  LN400EM/BE9L, Zuni, NM (XNI) to Albuquerque, N...
# 19    380  Aircraft observed a green/white quadcopter uas...
# 20    400  Aircraft observed a uas 1/4 NM S of the approa...
# 21    426  Aircraft observed a uas off the left side whil...
#
#                UAS_Location_Runways      UASLOCATION  IDENT RWYLOCATION  \
# 0                         ['RWY7R']      1 NM S  DVT    NaN     RWY 07R
# 1                         ['RWY9L']    1 NM W of OPF    NaN     RWY 09L
# 2                         ['RWY18']    1/2 NM S  PIE    NaN      RWY 18
# 3                        ['RWY31L']  6 NM ESE of RHV    NaN     RWY 31L
# 4                         ['RWY22']     6 NM NE  LGA    NaN      RWY 22
# 5                        ['RWY10R']    1 NM S of FLL    NaN     RWY 10R
# 6                 ['RWY 5R', 'RWY']   2 NM SW of RDU    NaN     RWY 05R
# 7                       ['RWY 24R']    2 NM E of LAX    NaN     RWY 24R
# 8                        ['RWY 22']    1 NM E of EAU    NaN      RWY 22
# 9                         ['RWY 7']    2 NM N of ORL    NaN      RWY 07
# 10                      ['RWY 17R']    1 NM W of COS    NaN     RWY 17R
# 11                       ['RWY17C']      4 NM N  DFW    NaN     RWY 17C
# 12                         ['RWY ']  .25 NM N of APA    NaN         NaN
# 13                        ['RWY18']    1 NM N of M01    NaN      RWY 18
# 14           ['RWY 10L', 'RWY 10R']    1 NM W of FLL    NaN     RWY 10L
# 15                       ['RWY01C']    7 NM S of IAD    NaN      RWY 01
# 16           ['RWY 18L', 'RWY 17R']    5 NM N of MCO    NaN     RWY 18L
# 17                        ['RWY18']      7 NM N  MCO    NaN      RWY 18
# 18                        ['RWY 3']    9 NM S of ABQ    NaN      RWY 03
# 19              ['RWY 27L', 'RWY ']  .25 NM W of OSU    NaN     RWY 27L
# 20                        ['RWY 8']  1/4 NM S of ABQ    NaN      RWY 08
# 21  ['RWY 17L', 'RWY18', 'RWY 17L']  1/8 NM E of MCO    NaN     RWY 17L
#
#       UAS_Distance    dateonly timeonly               DATE  ...  \
# 0         ['1 NM']    1/8/2018     2:42  2018-01-08T02:42Z  ...
# 1          ['1NM']    3/1/2018    22:20  2018-03-01T22:20Z  ...
# 2         ['2 NM']    4/3/2018    22:15  2018-04-03T22:15Z  ...
# 3         ['6 NM']   6/14/2018    10:18  2018-06-14T10:18Z  ...
# 4               []  10/17/2018     0:47  2018-10-17T00:47Z  ...
# 5          ['2NM']  12/25/2018    10:28  2018-12-25T10:28Z  ...
# 6   ['2NM', '2NM']   5/14/2019    23:18  2019-05-14T23:18Z  ...
# 7         ['2 NM']  11/29/2019    16:43  2019-11-29T16:43Z  ...
# 8          ['1NM']    7/4/2020    15:36  2020-07-04T15:36Z  ...
# 9         ['2 NM']   9/27/2020    12:48  2020-09-27T12:48Z  ...
# 10         ['1NM']   10/1/2020    20:01  2020-10-01T20:01Z  ...
# 11        ['4 NM']   11/2/2020    20:30  2020-11-02T20:30Z  ...
# 12      ['.25 NM']   1/13/2021    19:39  2021-01-13T19:39Z  ...
# 13        ['1 NM']   1/29/2021    17:50  2021-01-29T17:50Z  ...
# 14        ['1 NM']    2/8/2021    19:36  2021-02-08T19:36Z  ...
# 15              []   2/14/2021    20:44  2021-02-14T20:44Z  ...
# 16        ['5 NM']   3/30/2021    17:28  2021-03-30T17:28Z  ...
# 17        ['7 NM']   3/30/2021    17:41  2021-03-30T17:41Z  ...
# 18        ['9 NM']    6/4/2021    23:47  2021-06-04T23:47Z  ...
# 19      ['.25 NM']   6/17/2021    17:36  2021-06-17T17:36Z  ...
# 20        ['4 NM']    7/3/2021     0:39  2021-07-03T00:39Z  ...
# 21        ['8 NM']    8/7/2021    15:30  2021-08-07T15:30Z  ...
#
#    UASFORMATION.CEDAR CLOSESTPROXIMITY.CEDAR UASWEIGHTGT55.CEDAR UASDIM.CEDAR  \
# 0                 NaN                    NaN                 NaN          NaN
# 1                 NaN                    NaN                 NaN          NaN
# 2                 NaN                    NaN                 NaN          NaN
# 3                 NaN                    NaN                 NaN          NaN
# 4                 NaN                    NaN                 NaN          NaN
# 5                 NaN                    NaN                 NaN          NaN
# 6                 NaN                    NaN                 NaN          NaN
# 7                 NaN                    NaN                 NaN          NaN
# 8                 NaN                    NaN                 NaN          NaN
# 9                 NaN                    NaN                 NaN          NaN
# 10                NaN                    NaN                 NaN          NaN
# 11                NaN                    NaN                 NaN          NaN
# 12                NaN                    NaN                 NaN          NaN
# 13                NaN                    NaN                 NaN          NaN
# 14                NaN                    NaN                 NaN          NaN
# 15                NaN                    NaN                 NaN          NaN
# 16                NaN                    NaN                 NaN          NaN
# 17                NaN                    NaN                 NaN          NaN
# 18                NaN                    NaN                 NaN          NaN
# 19                NaN                    NaN                 NaN          NaN
# 20                NaN                    NaN                 NaN          NaN
# 21                NaN                    NaN                 NaN          NaN
#
#     UASFWROTOR.CEDAR  PILOTREPORTEDNMAC.CEDAR  TCASRA.CEDAR  SUMMARY.CEDAR  \
# 0                NaN                      NaN           NaN            NaN
# 1                NaN                      NaN           NaN            NaN
# 2                NaN                      NaN           NaN            NaN
# 3                NaN                      NaN           NaN            NaN
# 4                NaN                      NaN           NaN            NaN
# 5                NaN                      NaN           NaN            NaN
# 6                NaN                      NaN           NaN            NaN
# 7                NaN                      NaN           NaN            NaN
# 8                NaN                      NaN           NaN            NaN
# 9                NaN                      NaN           NaN            NaN
# 10               NaN                      NaN           NaN            NaN
# 11               NaN                      NaN           NaN            NaN
# 12               NaN                      NaN           NaN            NaN
# 13               NaN                      NaN           NaN            NaN
# 14               NaN                      NaN           NaN            NaN
# 15               NaN                      NaN           NaN            NaN
# 16               NaN                      NaN           NaN            NaN
# 17               NaN                      NaN           NaN            NaN
# 18               NaN                      NaN           NaN            NaN
# 19               NaN                      NaN           NaN            NaN
# 20               NaN                      NaN           NaN            NaN
# 21               NaN                      NaN           NaN            NaN
#
#     QAFINDINGS.CEDAR  DATASET
# 0                NaN   RUNWAY
# 1                NaN   RUNWAY
# 2                NaN   RUNWAY
# 3                NaN   RUNWAY
# 4                NaN   RUNWAY
# 5                NaN   RUNWAY
# 6                NaN   RUNWAY
# 7                NaN   RUNWAY
# 8                NaN   RUNWAY
# 9                NaN   RUNWAY
# 10               NaN   RUNWAY
# 11               NaN   RUNWAY
# 12               NaN  AIRPORT
# 13               NaN   RUNWAY
# 14               NaN   RUNWAY
# 15               NaN   RUNWAY
# 16               NaN   RUNWAY
# 17               NaN   RUNWAY
# 18               NaN   RUNWAY
# 19               NaN   RUNWAY
# 20               NaN   RUNWAY
# 21               NaN   RUNWAY
#
# [22 rows x 40 columns]

# %%
rwy22 = rwy22_allrows[['REMARKS', 'UASLOCATION', 'IDENT', 'RWYLOCATION']]
rwy22
# Out:
#                                               REMARKS      UASLOCATION  IDENT  \
# 0   Aircraft reported a uasmaneuvering 300 feet be...      1 NM S  DVT    NaN
# 1   Aircraft reported a black and red four rotor u...    1 NM W of OPF    NaN
# 2   Aircraft reported a shiny uas at same altitude...    1/2 NM S  PIE    NaN
# 3   Aircraft reported a white 4 rotor uas approxim...  6 NM ESE of RHV    NaN
# 4   Aircraft reported a uas off the left side at 1...     6 NM NE  LGA    NaN
# 5   Aircraft reported a uas hovering at approximat...    1 NM S of FLL    NaN
# 6   Aircraft reported a white and brown quad-copte...   2 NM SW of RDU    NaN
# 7   Aircraft observed a black uas while SW bound a...    2 NM E of LAX    NaN
# 8   Aircraft observed a uas while NE bound in a le...    1 NM E of EAU    NaN
# 9   Aircraft observed a uas below while W bound on...    2 NM N of ORL    NaN
# 10  Aircraft observed a white uas at 7,100 feet of...    1 NM W of COS    NaN
# 11  Aircraft observed a small uas directly below w...      4 NM N  DFW    NaN
# 12  Aircraft observed a quad copter uas off the ri...  .25 NM N of APA    NaN
# 13  Aircraft observed a white uas while S bound at...    1 NM N of M01    NaN
# 14  1836 Aircraft observed a uas off the right sid...    1 NM W of FLL    NaN
# 15  Aircraft observed a uas on 7 NM final to RWY 0...    7 NM S of IAD    NaN
# 16  Aircraft observed a uas off the right side whi...    5 NM N of MCO    NaN
# 17  Aircraft observed a uas off the left side whil...      7 NM N  MCO    NaN
# 18  LN400EM/BE9L, Zuni, NM (XNI) to Albuquerque, N...    9 NM S of ABQ    NaN
# 19  Aircraft observed a green/white quadcopter uas...  .25 NM W of OSU    NaN
# 20  Aircraft observed a uas 1/4 NM S of the approa...  1/4 NM S of ABQ    NaN
# 21  Aircraft observed a uas off the left side whil...  1/8 NM E of MCO    NaN
#
#    RWYLOCATION
# 0      RWY 07R
# 1      RWY 09L
# 2       RWY 18
# 3      RWY 31L
# 4       RWY 22
# 5      RWY 10R
# 6      RWY 05R
# 7      RWY 24R
# 8       RWY 22
# 9       RWY 07
# 10     RWY 17R
# 11     RWY 17C
# 12         NaN
# 13      RWY 18
# 14     RWY 10L
# 15      RWY 01
# 16     RWY 18L
# 17      RWY 18
# 18      RWY 03
# 19     RWY 27L
# 20      RWY 08
# 21     RWY 17L

# %%
for i in range(len(rwy22)):
    rwy22['IDENT'].loc[i] = rwy22['UASLOCATION'].loc[i].split()[-1]
rwy22
# Out:
# C:\Users\grace\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-11-b905e2e242af>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwy22['IDENT'].loc[i] = rwy22['UASLOCATION'].loc[i].split()[-1]
#                                               REMARKS      UASLOCATION IDENT  \
# 0   Aircraft reported a uasmaneuvering 300 feet be...      1 NM S  DVT   DVT
# 1   Aircraft reported a black and red four rotor u...    1 NM W of OPF   OPF
# 2   Aircraft reported a shiny uas at same altitude...    1/2 NM S  PIE   PIE
# 3   Aircraft reported a white 4 rotor uas approxim...  6 NM ESE of RHV   RHV
# 4   Aircraft reported a uas off the left side at 1...     6 NM NE  LGA   LGA
# 5   Aircraft reported a uas hovering at approximat...    1 NM S of FLL   FLL
# 6   Aircraft reported a white and brown quad-copte...   2 NM SW of RDU   RDU
# 7   Aircraft observed a black uas while SW bound a...    2 NM E of LAX   LAX
# 8   Aircraft observed a uas while NE bound in a le...    1 NM E of EAU   EAU
# 9   Aircraft observed a uas below while W bound on...    2 NM N of ORL   ORL
# 10  Aircraft observed a white uas at 7,100 feet of...    1 NM W of COS   COS
# 11  Aircraft observed a small uas directly below w...      4 NM N  DFW   DFW
# 12  Aircraft observed a quad copter uas off the ri...  .25 NM N of APA   APA
# 13  Aircraft observed a white uas while S bound at...    1 NM N of M01   M01
# 14  1836 Aircraft observed a uas off the right sid...    1 NM W of FLL   FLL
# 15  Aircraft observed a uas on 7 NM final to RWY 0...    7 NM S of IAD   IAD
# 16  Aircraft observed a uas off the right side whi...    5 NM N of MCO   MCO
# 17  Aircraft observed a uas off the left side whil...      7 NM N  MCO   MCO
# 18  LN400EM/BE9L, Zuni, NM (XNI) to Albuquerque, N...    9 NM S of ABQ   ABQ
# 19  Aircraft observed a green/white quadcopter uas...  .25 NM W of OSU   OSU
# 20  Aircraft observed a uas 1/4 NM S of the approa...  1/4 NM S of ABQ   ABQ
# 21  Aircraft observed a uas off the left side whil...  1/8 NM E of MCO   MCO
#
#    RWYLOCATION
# 0      RWY 07R
# 1      RWY 09L
# 2       RWY 18
# 3      RWY 31L
# 4       RWY 22
# 5      RWY 10R
# 6      RWY 05R
# 7      RWY 24R
# 8       RWY 22
# 9       RWY 07
# 10     RWY 17R
# 11     RWY 17C
# 12         NaN
# 13      RWY 18
# 14     RWY 10L
# 15      RWY 01
# 16     RWY 18L
# 17      RWY 18
# 18      RWY 03
# 19     RWY 27L
# 20      RWY 08
# 21     RWY 17L

# %%
rwy22
# Out:
#                                               REMARKS      UASLOCATION IDENT  \
# 0   Aircraft reported a uasmaneuvering 300 feet be...      1 NM S  DVT   DVT
# 1   Aircraft reported a black and red four rotor u...    1 NM W of OPF   OPF
# 2   Aircraft reported a shiny uas at same altitude...    1/2 NM S  PIE   PIE
# 3   Aircraft reported a white 4 rotor uas approxim...  6 NM ESE of RHV   RHV
# 4   Aircraft reported a uas off the left side at 1...     6 NM NE  LGA   LGA
# 5   Aircraft reported a uas hovering at approximat...    1 NM S of FLL   FLL
# 6   Aircraft reported a white and brown quad-copte...   2 NM SW of RDU   RDU
# 7   Aircraft observed a black uas while SW bound a...    2 NM E of LAX   LAX
# 8   Aircraft observed a uas while NE bound in a le...    1 NM E of EAU   EAU
# 9   Aircraft observed a uas below while W bound on...    2 NM N of ORL   ORL
# 10  Aircraft observed a white uas at 7,100 feet of...    1 NM W of COS   COS
# 11  Aircraft observed a small uas directly below w...      4 NM N  DFW   DFW
# 12  Aircraft observed a quad copter uas off the ri...  .25 NM N of APA   APA
# 13  Aircraft observed a white uas while S bound at...    1 NM N of M01   M01
# 14  1836 Aircraft observed a uas off the right sid...    1 NM W of FLL   FLL
# 15  Aircraft observed a uas on 7 NM final to RWY 0...    7 NM S of IAD   IAD
# 16  Aircraft observed a uas off the right side whi...    5 NM N of MCO   MCO
# 17  Aircraft observed a uas off the left side whil...      7 NM N  MCO   MCO
# 18  LN400EM/BE9L, Zuni, NM (XNI) to Albuquerque, N...    9 NM S of ABQ   ABQ
# 19  Aircraft observed a green/white quadcopter uas...  .25 NM W of OSU   OSU
# 20  Aircraft observed a uas 1/4 NM S of the approa...  1/4 NM S of ABQ   ABQ
# 21  Aircraft observed a uas off the left side whil...  1/8 NM E of MCO   MCO
#
#    RWYLOCATION
# 0      RWY 07R
# 1      RWY 09L
# 2       RWY 18
# 3      RWY 31L
# 4       RWY 22
# 5      RWY 10R
# 6      RWY 05R
# 7      RWY 24R
# 8       RWY 22
# 9       RWY 07
# 10     RWY 17R
# 11     RWY 17C
# 12         NaN
# 13      RWY 18
# 14     RWY 10L
# 15      RWY 01
# 16     RWY 18L
# 17      RWY 18
# 18      RWY 03
# 19     RWY 27L
# 20      RWY 08
# 21     RWY 17L

# %%
dist_list = []

for i in range(len(rwy22)):
    uas_dist = rwy22['UASLOCATION'].loc[i].split()[0]
    dist_list.append(uas_dist)
    
for i in range(len(dist_list)):
    if '/' in dist_list[i]:
        x = Fraction(dist_list[i])
        dist_list[i] = float(x)

rwy22['Distance_NM'] = dist_list
# Out:
# <ipython-input-30-9133590d5ed8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rwy22['Distance_NM'] = dist_list

# %%
rwy22
# Out:
#                                               REMARKS      UASLOCATION IDENT  \
# 0   Aircraft reported a uasmaneuvering 300 feet be...      1 NM S  DVT   DVT
# 1   Aircraft reported a black and red four rotor u...    1 NM W of OPF   OPF
# 2   Aircraft reported a shiny uas at same altitude...    1/2 NM S  PIE   PIE
# 3   Aircraft reported a white 4 rotor uas approxim...  6 NM ESE of RHV   RHV
# 4   Aircraft reported a uas off the left side at 1...     6 NM NE  LGA   LGA
# 5   Aircraft reported a uas hovering at approximat...    1 NM S of FLL   FLL
# 6   Aircraft reported a white and brown quad-copte...   2 NM SW of RDU   RDU
# 7   Aircraft observed a black uas while SW bound a...    2 NM E of LAX   LAX
# 8   Aircraft observed a uas while NE bound in a le...    1 NM E of EAU   EAU
# 9   Aircraft observed a uas below while W bound on...    2 NM N of ORL   ORL
# 10  Aircraft observed a white uas at 7,100 feet of...    1 NM W of COS   COS
# 11  Aircraft observed a small uas directly below w...      4 NM N  DFW   DFW
# 12  Aircraft observed a quad copter uas off the ri...  .25 NM N of APA   APA
# 13  Aircraft observed a white uas while S bound at...    1 NM N of M01   M01
# 14  1836 Aircraft observed a uas off the right sid...    1 NM W of FLL   FLL
# 15  Aircraft observed a uas on 7 NM final to RWY 0...    7 NM S of IAD   IAD
# 16  Aircraft observed a uas off the right side whi...    5 NM N of MCO   MCO
# 17  Aircraft observed a uas off the left side whil...      7 NM N  MCO   MCO
# 18  LN400EM/BE9L, Zuni, NM (XNI) to Albuquerque, N...    9 NM S of ABQ   ABQ
# 19  Aircraft observed a green/white quadcopter uas...  .25 NM W of OSU   OSU
# 20  Aircraft observed a uas 1/4 NM S of the approa...  1/4 NM S of ABQ   ABQ
# 21  Aircraft observed a uas off the left side whil...  1/8 NM E of MCO   MCO
#
#    RWYLOCATION Distance_NM
# 0      RWY 07R           1
# 1      RWY 09L           1
# 2       RWY 18         0.5
# 3      RWY 31L           6
# 4       RWY 22           6
# 5      RWY 10R           1
# 6      RWY 05R           2
# 7      RWY 24R           2
# 8       RWY 22           1
# 9       RWY 07           2
# 10     RWY 17R           1
# 11     RWY 17C           4
# 12         NaN         .25
# 13      RWY 18           1
# 14     RWY 10L           1
# 15      RWY 01           7
# 16     RWY 18L           5
# 17      RWY 18           7
# 18      RWY 03           9
# 19     RWY 27L         .25
# 20      RWY 08        0.25
# 21     RWY 17L       0.125

# %%
def drop_nan(dataframe):
    '''
    This function replaces all instances of [] in the dataframe provided as
    input with NaN and then returns a new dataframe with no 'NaN' values
    
    input : dataframe is a dataframe containing UAS remark information
    output : a new dataframe with no 'NaN' values
    '''
    
    df1 = dataframe.mask(dataframe.applymap(str).eq('[]'))
    output_df = df1.dropna().reset_index(drop=True)
    
    return output_df

# %%
rwy21 = drop_nan(rwy22)
rwy21
# Out:
#                                               REMARKS      UASLOCATION IDENT  \
# 0   Aircraft reported a uasmaneuvering 300 feet be...      1 NM S  DVT   DVT
# 1   Aircraft reported a black and red four rotor u...    1 NM W of OPF   OPF
# 2   Aircraft reported a shiny uas at same altitude...    1/2 NM S  PIE   PIE
# 3   Aircraft reported a white 4 rotor uas approxim...  6 NM ESE of RHV   RHV
# 4   Aircraft reported a uas off the left side at 1...     6 NM NE  LGA   LGA
# 5   Aircraft reported a uas hovering at approximat...    1 NM S of FLL   FLL
# 6   Aircraft reported a white and brown quad-copte...   2 NM SW of RDU   RDU
# 7   Aircraft observed a black uas while SW bound a...    2 NM E of LAX   LAX
# 8   Aircraft observed a uas while NE bound in a le...    1 NM E of EAU   EAU
# 9   Aircraft observed a uas below while W bound on...    2 NM N of ORL   ORL
# 10  Aircraft observed a white uas at 7,100 feet of...    1 NM W of COS   COS
# 11  Aircraft observed a small uas directly below w...      4 NM N  DFW   DFW
# 12  Aircraft observed a white uas while S bound at...    1 NM N of M01   M01
# 13  1836 Aircraft observed a uas off the right sid...    1 NM W of FLL   FLL
# 14  Aircraft observed a uas on 7 NM final to RWY 0...    7 NM S of IAD   IAD
# 15  Aircraft observed a uas off the right side whi...    5 NM N of MCO   MCO
# 16  Aircraft observed a uas off the left side whil...      7 NM N  MCO   MCO
# 17  LN400EM/BE9L, Zuni, NM (XNI) to Albuquerque, N...    9 NM S of ABQ   ABQ
# 18  Aircraft observed a green/white quadcopter uas...  .25 NM W of OSU   OSU
# 19  Aircraft observed a uas 1/4 NM S of the approa...  1/4 NM S of ABQ   ABQ
# 20  Aircraft observed a uas off the left side whil...  1/8 NM E of MCO   MCO
#
#    RWYLOCATION Distance_NM
# 0      RWY 07R           1
# 1      RWY 09L           1
# 2       RWY 18         0.5
# 3      RWY 31L           6
# 4       RWY 22           6
# 5      RWY 10R           1
# 6      RWY 05R           2
# 7      RWY 24R           2
# 8       RWY 22           1
# 9       RWY 07           2
# 10     RWY 17R           1
# 11     RWY 17C           4
# 12      RWY 18           1
# 13     RWY 10L           1
# 14      RWY 01           7
# 15     RWY 18L           5
# 16      RWY 18           7
# 17      RWY 03           9
# 18     RWY 27L         .25
# 19      RWY 08        0.25
# 20     RWY 17L       0.125

# %%
def airRwy_link (dataframe):
    '''
    This function does the following:
        1. Merge the dataframe with the airports_runways_linked.csv dataset
            a. Merge in the IDENT field
        2. Extracts the Runway Designator from RWYLOCATION field
        3. Checks if the Runway Designator found in the Remark matches one
           of the RWY Designators from airports_runways_linked.csv
            a. Only keeps those records for which there is a match
        4. Merge the resulting dataframe with airports_cleaned_declination.csv
           to get the declination for the runway
    
    input : dataframe is a dataframe containing UAS remark information and 
            Runway Location information in a field named RWYLOCATION
    output : a new dataframe in which all records have a runway location
             that is present at an airport in airports_runways_linked.csv
    '''
    # Import and store datasets to merge with
    air_rwy = pd.read_csv('C:/Users/grace/OneDrive/Desktop/GMU/DAEN690/airports_runways_linked.csv')
    air_dec = pd.read_csv('C:/Users/grace/OneDrive/Desktop/GMU/DAEN690/airports_cleaned_declination.csv')
    
    # Merge the two datasets on the 'IDENT' field
    rwy_linked = pd.merge(dataframe, air_rwy, on = 'IDENT', how = 'left')
    rwy_linked.rename(columns = {'properties.DESIGNATOR': 'DESIGNATOR'}, inplace = True)
    
    # Extract Runway Designator from RWYLOCATION field
    rwydesignator = []

    for i in range(len(rwy_linked)):
        rwy_split = rwy_linked['RWYLOCATION'][i].split(' ')
        rwydesignator.append(rwy_split[1])

    # Add split column with RWY designators to dataframe as new field
    rwy_linked['RWYDESIGNATOR'] = rwydesignator
    
    # Check if Runway Designator found in Remark matches one of the Runway designators
    # from the air_rwy dataframe
    rwy_linked['RWYinREMARK'] = rwy_linked.apply(lambda x: str(x.RWYDESIGNATOR) in str(x.DESIGNATOR), axis=1)

    # Only keep records for which the RWY Designator is present in the DESIGNATOR field 
    output_df1 = rwy_linked[rwy_linked['RWYinREMARK'] == True]
    
    # Merge resulting dataframe with airport declination (air_dec) dataframe
    output_dec = pd.merge(output_df1, air_dec, on = 'IDENT', how = 'left')
    
    # Only keep necessary columns/fields of interest
    output_df = pd.DataFrame(output_dec[['REMARKS', 'UASLOCATION', 'IDENT', 'RWYLOCATION', 'Distance_NM', 'RWYDESIGNATOR', 'Runway.Latitude', 'Runway.Longitude', 'DECLINATION']])
    
    return output_df

# %%
rwy20 = airRwy_link(rwy21).drop_duplicates(subset=['REMARKS']).reset_index(drop=True)
rwy20
# Out:
#                                               REMARKS      UASLOCATION IDENT  \
# 0   Aircraft reported a uasmaneuvering 300 feet be...      1 NM S  DVT   DVT
# 1   Aircraft reported a black and red four rotor u...    1 NM W of OPF   OPF
# 2   Aircraft reported a shiny uas at same altitude...    1/2 NM S  PIE   PIE
# 3   Aircraft reported a white 4 rotor uas approxim...  6 NM ESE of RHV   RHV
# 4   Aircraft reported a uas off the left side at 1...     6 NM NE  LGA   LGA
# 5   Aircraft reported a uas hovering at approximat...    1 NM S of FLL   FLL
# 6   Aircraft reported a white and brown quad-copte...   2 NM SW of RDU   RDU
# 7   Aircraft observed a black uas while SW bound a...    2 NM E of LAX   LAX
# 8   Aircraft observed a uas while NE bound in a le...    1 NM E of EAU   EAU
# 9   Aircraft observed a uas below while W bound on...    2 NM N of ORL   ORL
# 10  Aircraft observed a white uas at 7,100 feet of...    1 NM W of COS   COS
# 11  Aircraft observed a small uas directly below w...      4 NM N  DFW   DFW
# 12  1836 Aircraft observed a uas off the right sid...    1 NM W of FLL   FLL
# 13  Aircraft observed a uas on 7 NM final to RWY 0...    7 NM S of IAD   IAD
# 14  Aircraft observed a uas off the right side whi...    5 NM N of MCO   MCO
# 15  Aircraft observed a uas off the left side whil...      7 NM N  MCO   MCO
# 16  LN400EM/BE9L, Zuni, NM (XNI) to Albuquerque, N...    9 NM S of ABQ   ABQ
# 17  Aircraft observed a green/white quadcopter uas...  .25 NM W of OSU   OSU
# 18  Aircraft observed a uas 1/4 NM S of the approa...  1/4 NM S of ABQ   ABQ
# 19  Aircraft observed a uas off the left side whil...  1/8 NM E of MCO   MCO
#
#    RWYLOCATION Distance_NM RWYDESIGNATOR  Runway.Latitude  Runway.Longitude  \
# 0      RWY 07R           1           07R      -112.085527         33.687439
# 1      RWY 09L           1           09L       -80.274087         25.913315
# 2       RWY 18         0.5            18       -82.688023         27.907540
# 3      RWY 31L           6           31L      -121.820886         37.333293
# 4       RWY 22           6            22       -73.878696         40.775660
# 5      RWY 10R           1           10R       -80.143732         26.065846
# 6      RWY 05R           2           05R       -78.790127         35.870421
# 7      RWY 24R           2           24R      -118.419482         33.950273
# 8       RWY 22           1            22       -91.483850         44.865552
# 9       RWY 07           2            07       -81.328953         28.546714
# 10     RWY 17R           1           17R      -104.715982         38.805931
# 11     RWY 17C           4           17C       -97.026110         32.900981
# 12     RWY 10L           1           10L       -80.155574         26.076850
# 13      RWY 01           7            01       -77.459557         38.958019
# 14     RWY 18L           5           18L       -81.322036         28.428531
# 15      RWY 18           7            18       -81.322036         28.428531
# 16      RWY 03           9            03      -106.621165         35.030022
# 17     RWY 27L         .25           27L       -83.074462         40.077408
# 18      RWY 08        0.25            08      -106.603173         35.044201
# 19     RWY 17L       0.125           17L       -81.282386         28.428851
#
#     DECLINATION
# 0      10.02699
# 1      -6.94323
# 2      -5.72372
# 3      13.05261
# 4     -12.75395
# 5      -7.04262
# 6      -9.22834
# 7      11.71212
# 8      -1.36005
# 9      -6.64984
# 10      7.64525
# 11      3.06900
# 12     -7.04262
# 13    -10.51776
# 14     -6.64939
# 15     -6.64939
# 16      8.16776
# 17     -7.11820
# 18      8.16776
# 19     -6.64939

# %%
def rwyUAS_latLong (dataframe):
    '''
    This function takes in a dataframe containing Runway latitude/longitude
    information as well as runway declination information for each Remark
    having a runway origin reference location.
    
    This function does the following:
        1. Calculates bearing information for each runway reference
        2. Converts distances from NM to kilometers
        3. Calculates UAS Latitude/Longitude information using geopy
    
    input : dataframe containing runway lat/long and declination information
    output : dataframe containing UAS Latitude/Longitude information
    '''
    # Calculate bearing information for each runway reference
    designator = dataframe['RWYDESIGNATOR']
    designator_bearing = []

    for i in range(len(dataframe)):
        designator_bearing.append(int(re.sub("\D","",designator[i]))*10 + dataframe['DECLINATION'][i])

    dataframe['RWY_BEARING'] = designator_bearing
    
    # Convert Distances from NM to kilometers
    dist_kilo = []

    for i in range(len(dataframe)):
        distanceKilo = int(re.sub("\D","",str(dataframe['Distance_NM'][i])))* 1.852 # converting NM to kilometers
        dist_kilo.append(distanceKilo)

    dataframe['Distance_Kilometers'] = dist_kilo
    
    # BECAUSE ERIC HAD THESE SWITCHED ****************
    dataframe.rename(columns = {'Runway.Latitude': 'Runway_Longitude', 'Runway.Longitude' : 'Runway_Latitude'}, inplace = True)
    
    # Calculate UAS Lat/Long information using geopy
    uas_lat = []
    uas_long = []


    for i in range(len(dataframe)):
        lat_rwy = pd.to_numeric(dataframe['Runway_Latitude'][i])
        long_rwy = pd.to_numeric(dataframe['Runway_Longitude'][i])
        b = pd.to_numeric(dataframe['RWY_BEARING'][i])
        d = pd.to_numeric(dataframe['Distance_Kilometers'][i])

        origin = geopy.Point(lat_rwy, long_rwy)
        destination = geodesic(kilometers=d).destination(origin,b)

        lat2, lon2, = destination.latitude, destination.longitude

        uas_lat.append(lat2)
        uas_long.append(lon2)

    # Append UAS Lat/Long information to DataFrame
    dataframe['UAS_Latitude'] = uas_lat
    dataframe['UAS_Longitude'] = uas_long
    
    # Export dataframe containing UAS lat/long information to .csv file 
    dataframe.to_csv('rwy%d_uasLatLong.csv'%len(dataframe), index=False)
    
    return dataframe

# %%
rwy20_uas = rwyUAS_latLong(rwy20)
rwy20_uas
# Out:
#                                               REMARKS      UASLOCATION IDENT  \
# 0   Aircraft reported a uasmaneuvering 300 feet be...      1 NM S  DVT   DVT
# 1   Aircraft reported a black and red four rotor u...    1 NM W of OPF   OPF
# 2   Aircraft reported a shiny uas at same altitude...    1/2 NM S  PIE   PIE
# 3   Aircraft reported a white 4 rotor uas approxim...  6 NM ESE of RHV   RHV
# 4   Aircraft reported a uas off the left side at 1...     6 NM NE  LGA   LGA
# 5   Aircraft reported a uas hovering at approximat...    1 NM S of FLL   FLL
# 6   Aircraft reported a white and brown quad-copte...   2 NM SW of RDU   RDU
# 7   Aircraft observed a black uas while SW bound a...    2 NM E of LAX   LAX
# 8   Aircraft observed a uas while NE bound in a le...    1 NM E of EAU   EAU
# 9   Aircraft observed a uas below while W bound on...    2 NM N of ORL   ORL
# 10  Aircraft observed a white uas at 7,100 feet of...    1 NM W of COS   COS
# 11  Aircraft observed a small uas directly below w...      4 NM N  DFW   DFW
# 12  1836 Aircraft observed a uas off the right sid...    1 NM W of FLL   FLL
# 13  Aircraft observed a uas on 7 NM final to RWY 0...    7 NM S of IAD   IAD
# 14  Aircraft observed a uas off the right side whi...    5 NM N of MCO   MCO
# 15  Aircraft observed a uas off the left side whil...      7 NM N  MCO   MCO
# 16  LN400EM/BE9L, Zuni, NM (XNI) to Albuquerque, N...    9 NM S of ABQ   ABQ
# 17  Aircraft observed a green/white quadcopter uas...  .25 NM W of OSU   OSU
# 18  Aircraft observed a uas 1/4 NM S of the approa...  1/4 NM S of ABQ   ABQ
# 19  Aircraft observed a uas off the left side whil...  1/8 NM E of MCO   MCO
#
#    RWYLOCATION Distance_NM RWYDESIGNATOR  Runway_Longitude  Runway_Latitude  \
# 0      RWY 07R           1           07R       -112.085527        33.687439
# 1      RWY 09L           1           09L        -80.274087        25.913315
# 2       RWY 18         0.5            18        -82.688023        27.907540
# 3      RWY 31L           6           31L       -121.820886        37.333293
# 4       RWY 22           6            22        -73.878696        40.775660
# 5      RWY 10R           1           10R        -80.143732        26.065846
# 6      RWY 05R           2           05R        -78.790127        35.870421
# 7      RWY 24R           2           24R       -118.419482        33.950273
# 8       RWY 22           1            22        -91.483850        44.865552
# 9       RWY 07           2            07        -81.328953        28.546714
# 10     RWY 17R           1           17R       -104.715982        38.805931
# 11     RWY 17C           4           17C        -97.026110        32.900981
# 12     RWY 10L           1           10L        -80.155574        26.076850
# 13      RWY 01           7            01        -77.459557        38.958019
# 14     RWY 18L           5           18L        -81.322036        28.428531
# 15      RWY 18           7            18        -81.322036        28.428531
# 16      RWY 03           9            03       -106.621165        35.030022
# 17     RWY 27L         .25           27L        -83.074462        40.077408
# 18      RWY 08        0.25            08       -106.603173        35.044201
# 19     RWY 17L       0.125           17L        -81.282386        28.428851
#
#     DECLINATION  RWY_BEARING  Distance_Kilometers  UAS_Latitude  UAS_Longitude
# 0      10.02699     80.02699                1.852     33.690329    -112.065855
# 1      -6.94323     83.05677                1.852     25.915335     -80.255737
# 2      -5.72372    174.27628                9.260     27.824396     -82.678650
# 3      13.05261    323.05261               11.112     37.413286    -121.896334
# 4     -12.75395    207.24605               11.112     40.686682     -73.938877
# 5      -7.04262     92.95738                1.852     26.064982     -80.125248
# 6      -9.22834     40.77166                3.704     35.895699     -78.763335
# 7      11.71212    251.71212                3.704     33.939789    -118.457523
# 8      -1.36005    218.63995                1.852     44.852534     -91.498479
# 9      -6.64984     63.35016                3.704     28.561701     -81.295120
# 10      7.64525    177.64525                1.852     38.789262    -104.715106
# 11      3.06900    173.06900                7.408     32.834672     -97.016562
# 12     -7.04262     92.95738                1.852     26.075986     -80.137089
# 13    -10.51776     -0.51776               12.964     39.074791     -77.460911
# 14     -6.64939    173.35061                9.260     28.345538     -81.311100
# 15     -6.64939    173.35061               12.964     28.312340     -81.306730
# 16      8.16776     38.16776               16.668     35.148089    -106.508128
# 17     -7.11820    262.88180               46.300     40.024486     -83.612673
# 18      8.16776     88.16776               46.300     35.056484    -106.095896
# 19     -6.64939    163.35061              231.500     26.425664     -80.617602

# %%
rwy_merge = df_all = rwy22.merge(rwy20_uas.drop_duplicates(), on=['REMARKS'], 
                   how='left', indicator=True)
rwy_merge
# Out:
#                                               REMARKS    UASLOCATION_x  \
# 0   Aircraft reported a uasmaneuvering 300 feet be...      1 NM S  DVT
# 1   Aircraft reported a black and red four rotor u...    1 NM W of OPF
# 2   Aircraft reported a shiny uas at same altitude...    1/2 NM S  PIE
# 3   Aircraft reported a white 4 rotor uas approxim...  6 NM ESE of RHV
# 4   Aircraft reported a uas off the left side at 1...     6 NM NE  LGA
# 5   Aircraft reported a uas hovering at approximat...    1 NM S of FLL
# 6   Aircraft reported a white and brown quad-copte...   2 NM SW of RDU
# 7   Aircraft observed a black uas while SW bound a...    2 NM E of LAX
# 8   Aircraft observed a uas while NE bound in a le...    1 NM E of EAU
# 9   Aircraft observed a uas below while W bound on...    2 NM N of ORL
# 10  Aircraft observed a white uas at 7,100 feet of...    1 NM W of COS
# 11  Aircraft observed a small uas directly below w...      4 NM N  DFW
# 12  Aircraft observed a quad copter uas off the ri...  .25 NM N of APA
# 13  Aircraft observed a white uas while S bound at...    1 NM N of M01
# 14  1836 Aircraft observed a uas off the right sid...    1 NM W of FLL
# 15  Aircraft observed a uas on 7 NM final to RWY 0...    7 NM S of IAD
# 16  Aircraft observed a uas off the right side whi...    5 NM N of MCO
# 17  Aircraft observed a uas off the left side whil...      7 NM N  MCO
# 18  LN400EM/BE9L, Zuni, NM (XNI) to Albuquerque, N...    9 NM S of ABQ
# 19  Aircraft observed a green/white quadcopter uas...  .25 NM W of OSU
# 20  Aircraft observed a uas 1/4 NM S of the approa...  1/4 NM S of ABQ
# 21  Aircraft observed a uas off the left side whil...  1/8 NM E of MCO
#
#    IDENT_x RWYLOCATION_x Distance_NM_x    UASLOCATION_y IDENT_y RWYLOCATION_y  \
# 0      DVT       RWY 07R             1      1 NM S  DVT     DVT       RWY 07R
# 1      OPF       RWY 09L             1    1 NM W of OPF     OPF       RWY 09L
# 2      PIE        RWY 18           0.5    1/2 NM S  PIE     PIE        RWY 18
# 3      RHV       RWY 31L             6  6 NM ESE of RHV     RHV       RWY 31L
# 4      LGA        RWY 22             6     6 NM NE  LGA     LGA        RWY 22
# 5      FLL       RWY 10R             1    1 NM S of FLL     FLL       RWY 10R
# 6      RDU       RWY 05R             2   2 NM SW of RDU     RDU       RWY 05R
# 7      LAX       RWY 24R             2    2 NM E of LAX     LAX       RWY 24R
# 8      EAU        RWY 22             1    1 NM E of EAU     EAU        RWY 22
# 9      ORL        RWY 07             2    2 NM N of ORL     ORL        RWY 07
# 10     COS       RWY 17R             1    1 NM W of COS     COS       RWY 17R
# 11     DFW       RWY 17C             4      4 NM N  DFW     DFW       RWY 17C
# 12     APA           NaN           .25              NaN     NaN           NaN
# 13     M01        RWY 18             1              NaN     NaN           NaN
# 14     FLL       RWY 10L             1    1 NM W of FLL     FLL       RWY 10L
# 15     IAD        RWY 01             7    7 NM S of IAD     IAD        RWY 01
# 16     MCO       RWY 18L             5    5 NM N of MCO     MCO       RWY 18L
# 17     MCO        RWY 18             7      7 NM N  MCO     MCO        RWY 18
# 18     ABQ        RWY 03             9    9 NM S of ABQ     ABQ        RWY 03
# 19     OSU       RWY 27L           .25  .25 NM W of OSU     OSU       RWY 27L
# 20     ABQ        RWY 08          0.25  1/4 NM S of ABQ     ABQ        RWY 08
# 21     MCO       RWY 17L         0.125  1/8 NM E of MCO     MCO       RWY 17L
#
#    Distance_NM_y RWYDESIGNATOR  Runway_Longitude  Runway_Latitude  \
# 0              1           07R       -112.085527        33.687439
# 1              1           09L        -80.274087        25.913315
# 2            0.5            18        -82.688023        27.907540
# 3              6           31L       -121.820886        37.333293
# 4              6            22        -73.878696        40.775660
# 5              1           10R        -80.143732        26.065846
# 6              2           05R        -78.790127        35.870421
# 7              2           24R       -118.419482        33.950273
# 8              1            22        -91.483850        44.865552
# 9              2            07        -81.328953        28.546714
# 10             1           17R       -104.715982        38.805931
# 11             4           17C        -97.026110        32.900981
# 12           NaN           NaN               NaN              NaN
# 13           NaN           NaN               NaN              NaN
# 14             1           10L        -80.155574        26.076850
# 15             7            01        -77.459557        38.958019
# 16             5           18L        -81.322036        28.428531
# 17             7            18        -81.322036        28.428531
# 18             9            03       -106.621165        35.030022
# 19           .25           27L        -83.074462        40.077408
# 20          0.25            08       -106.603173        35.044201
# 21         0.125           17L        -81.282386        28.428851
#
#     DECLINATION  RWY_BEARING  Distance_Kilometers  UAS_Latitude  \
# 0      10.02699     80.02699                1.852     33.690329
# 1      -6.94323     83.05677                1.852     25.915335
# 2      -5.72372    174.27628                9.260     27.824396
# 3      13.05261    323.05261               11.112     37.413286
# 4     -12.75395    207.24605               11.112     40.686682
# 5      -7.04262     92.95738                1.852     26.064982
# 6      -9.22834     40.77166                3.704     35.895699
# 7      11.71212    251.71212                3.704     33.939789
# 8      -1.36005    218.63995                1.852     44.852534
# 9      -6.64984     63.35016                3.704     28.561701
# 10      7.64525    177.64525                1.852     38.789262
# 11      3.06900    173.06900                7.408     32.834672
# 12          NaN          NaN                  NaN           NaN
# 13          NaN          NaN                  NaN           NaN
# 14     -7.04262     92.95738                1.852     26.075986
# 15    -10.51776     -0.51776               12.964     39.074791
# 16     -6.64939    173.35061                9.260     28.345538
# 17     -6.64939    173.35061               12.964     28.312340
# 18      8.16776     38.16776               16.668     35.148089
# 19     -7.11820    262.88180               46.300     40.024486
# 20      8.16776     88.16776               46.300     35.056484
# 21     -6.64939    163.35061              231.500     26.425664
#
#     UAS_Longitude     _merge
# 0     -112.065855       both
# 1      -80.255737       both
# 2      -82.678650       both
# 3     -121.896334       both
# 4      -73.938877       both
# 5      -80.125248       both
# 6      -78.763335       both
# 7     -118.457523       both
# 8      -91.498479       both
# 9      -81.295120       both
# 10    -104.715106       both
# 11     -97.016562       both
# 12            NaN  left_only
# 13            NaN  left_only
# 14     -80.137089       both
# 15     -77.460911       both
# 16     -81.311100       both
# 17     -81.306730       both
# 18    -106.508128       both
# 19     -83.612673       both
# 20    -106.095896       both
# 21     -80.617602       both

# %%
rwy_unid2 = rwy_merge[rwy_merge['_merge'] == 'left_only'].reset_index(drop=True)
rwy_unid2
# Out:
#                                              REMARKS    UASLOCATION_x IDENT_x  \
# 0  Aircraft observed a quad copter uas off the ri...  .25 NM N of APA     APA
# 1  Aircraft observed a white uas while S bound at...    1 NM N of M01     M01
#
#   RWYLOCATION_x Distance_NM_x UASLOCATION_y IDENT_y RWYLOCATION_y  \
# 0           NaN           .25           NaN     NaN           NaN
# 1        RWY 18             1           NaN     NaN           NaN
#
#   Distance_NM_y RWYDESIGNATOR  Runway_Longitude  Runway_Latitude  DECLINATION  \
# 0           NaN           NaN               NaN              NaN          NaN
# 1           NaN           NaN               NaN              NaN          NaN
#
#    RWY_BEARING  Distance_Kilometers  UAS_Latitude  UAS_Longitude     _merge
# 0          NaN                  NaN           NaN            NaN  left_only
# 1          NaN                  NaN           NaN            NaN  left_only

# %%
# Export to .csv file 
rwy_unid2.to_csv('rwy2of302_EXCEPTIONS.csv', index=False)
