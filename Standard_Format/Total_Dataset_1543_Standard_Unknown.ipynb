# %%
# Import Statements
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import chart_studio.plotly as py
import re

from IPython.display import display, HTML

# %%
unkn_std_fmt = pd.read_csv('C:/Users/grace/OneDrive/Desktop/GMU/DAEN690/unkn_std_format.csv')
faa_standard = pd.read_csv('C:/Users/grace/OneDrive/Desktop/GMU/DAEN690/Incidents_Cleaned_Standard_NoDuplicates.csv')

# %%
unkn_std_fmt
# Out:
#       index                                            REMARKS  \
# 0         1  Aircraft observed a UAS operating 400 feet bel...
# 1         2  Aircraft observed a black UAS 4-5 feet in diam...
# 2         6  Aircraft observed an orange UAS below and to t...
# 3         9  Aircraft observed a small UAS with lights whil...
# 4        10  Aircraft observed a UAS while WNW bound at 4,5...
# ...     ...                                                ...
# 1538   2128  Aircraft reported a quad-copter UAS approximat...
# 1539   2130  Aircraft reported a UAS off the left side, whi...
# 1540   2133  Aircraft reported a dark blue UAS at 12 o'cloc...
# 1541   2138  Aircraft reported a black UAS with red lights ...
# 1542   2141  Aircraft reported a 50' diameter white balloon...
#
#      UAS_Location_Runways
# 0                    UNKN
# 1                    UNKN
# 2                    UNKN
# 3                    UNKN
# 4                    UNKN
# ...                   ...
# ...

# %%
faa_standard
# Out:
#        dateonly timeonly               DATE  POD  \
# 0      1/1/2018    10:46  2018-01-01T10:46Z  DEN
# 1      1/1/2018    14:37  2018-01-01T14:37Z  DEN
# 2     1/13/2018    12:04  2018-01-13T12:04Z  DEN
# 3     1/15/2018     8:52  2018-01-15T08:52Z  DEN
# 4     1/17/2018     1:25  2018-01-17T01:25Z  DEN
# ...         ...      ...                ...  ...
# 5162  6/21/2020    18:30  2020-06-21T18:30Z  DEN
# 5163  7/31/2020    20:47  2020-07-31T20:47Z  DEN
# 5164   4/6/2021    18:07  2021-04-06T18:07Z  DEN
# 5165  4/20/2021    18:39  2021-04-20T18:39Z  DEN
# 5166   6/9/2021     2:01  2021-06-09T02:01Z  DEN
#
#                          PRIMARYCODE     SECONDARYCODES REPORTINGFACILITY  \
# 0                                UAS                NaN               CLE
# 1                                UAS                NaN               SLC
# 2                                UAS                NaN               SJC
# 3                                UAS                NaN               POC
# ...

# %%
unknown_standard_complete = pd.merge(unkn_std_fmt, faa_standard, on='REMARKS', how='left')

# %%
unknown_standard_complete
# Out:
#       index                                            REMARKS  \
# 0         1  Aircraft observed a UAS operating 400 feet bel...
# 1         2  Aircraft observed a black UAS 4-5 feet in diam...
# 2         6  Aircraft observed an orange UAS below and to t...
# 3         9  Aircraft observed a small UAS with lights whil...
# 4        10  Aircraft observed a UAS while WNW bound at 4,5...
# ...     ...                                                ...
# 1538   2128  Aircraft reported a quad-copter UAS approximat...
# 1539   2130  Aircraft reported a UAS off the left side, whi...
# 1540   2133  Aircraft reported a dark blue UAS at 12 o'cloc...
# 1541   2138  Aircraft reported a black UAS with red lights ...
# 1542   2141  Aircraft reported a 50' diameter white balloon...
#
#      UAS_Location_Runways    dateonly timeonly               DATE  POD  \
# 0                    UNKN   1/15/2018     8:52  2018-01-15T08:52Z  DEN
# ...

# %%
# Export to .csv file
unknown_standard_complete.to_csv('unknown_standard_complete.csv', index = False)
